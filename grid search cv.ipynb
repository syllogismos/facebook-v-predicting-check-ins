# %%
cd scripts/
# Out:
# /home/ubuntu/facebook/scripts

# %%
import grid_search as gs
import traceback
# Out:
# (14363, 6) card_train_shape
# (16178, 6) train_shape
# (331, 6) test_shape
# (14363, 12) X shape
# (14363, 1) y shape
# (331, 12) test_X shape
# (331, 1) test_y shape
# 770

# %%
param_range1 = {
    'max_depth': range(8, 15),
    'min_child_weight': range(4, 8)
}

param_range2 = {
    'gamma': [i/100.0 for i in range(20, 40, 3)]
}

param_range3 = {
    'scale_pos_weight': range(1, 10)
}

param_range4 = {
    'subsample': [i/100.0 for i in range(50, 100, 5)],
    'colsample_bytree': [i/100.0 for i in range(55, 100, 5)]
}

param_range5 = {
 'alpha':[0, 1e-5, 0.001, 0.005, 0.01, 0.05, 0.1, 1, 100]
}

# %%
try:
    result1 = gs.grid_search_xgb(param_range1)
except Exception, e:
    print e
    print traceback.format_exc()
# Out:
# cv results {'map': 0.76388599999999995, 'max_depth': 8, 'min_child_weight': 4}
# cv results {'map': 0.76193433333333338, 'max_depth': 8, 'min_child_weight': 6}
# cv results {'map': 0.76235266666666668, 'max_depth': 9, 'min_child_weight': 6}
# cv results {'map': 0.76416466666666671, 'max_depth': 9, 'min_child_weight': 4}
# cv results {'map': 0.76562833333333336, 'max_depth': 8, 'min_child_weight': 5}
# cv results {'map': 0.76158599999999999, 'max_depth': 9, 'min_child_weight': 7}
# cv results {'map': 0.761656, 'max_depth': 8, 'min_child_weight': 7}
# cv results {'map': 0.76472266666666666, 'max_depth': 9, 'min_child_weight': 5}
# cv results {'map': 0.76486166666666666, 'max_depth': 10, 'min_child_weight': 4}
# cv results {'map': 0.76277099999999998, 'max_depth': 10, 'min_child_weight': 6}
# cv results {'map': 0.76277099999999998, 'max_depth': 11, 'min_child_weight': 6}
# cv results {'map': 0.7637463333333333, 'max_depth': 11, 'min_child_weight': 4}
# cv results {'map': 0.76395599999999997, 'max_depth': 10, 'min_child_weight': 5}
# cv results {'map': 0.76193433333333338, 'max_depth': 10, 'min_child_weight': 7}
# cv results {'map': 0.76207400000000003, 'max_depth': 11, 'min_child_weight': 7}
# cv results {'map': 0.76534966666666671, 'max_depth': 11, 'min_child_weight': 5}
# cv results {'map': 0.76388599999999995, 'max_depth': 12, 'min_child_weight': 4}
# cv results {'map': 0.76270133333333323, 'max_depth': 12, 'min_child_weight': 6}
# cv results {'map': 0.76311966666666675, 'max_depth': 13, 'min_child_weight': 6}
# cv results {'map': 0.76465266666666665, 'max_depth': 13, 'min_child_weight': 4}
# cv results {'map': 0.76534966666666671, 'max_depth': 12, 'min_child_weight': 5}
# cv results {'map': 0.76207400000000003, 'max_depth': 13, 'min_child_weight': 7}
# cv results {'map': 0.76095900000000005, 'max_depth': 12, 'min_child_weight': 7}
# cv results {'map': 0.7649313333333333, 'max_depth': 13, 'min_child_weight': 5}
# cv results {'map': 0.76444366666666663, 'max_depth': 14, 'min_child_weight': 4}
# cv results {'map': 0.76291033333333347, 'max_depth': 14, 'min_child_weight': 6}
# cv results {'map': 0.76409499999999986, 'max_depth': 14, 'min_child_weight': 5}
# cv results {'map': 0.76165566666666662, 'max_depth': 14, 'min_child_weight': 7}
# top map results [{'map': 0.76562833333333336, 'max_depth': 8, 'min_child_weight': 5}, {'map': 0.76534966666666671, 'max_depth': 11, 'min_child_weight': 5}, {'map': 0.76534966666666671, 'max_depth': 12, 'min_child_weight': 5}]
# cv results {'map': 0.76437366666666673, 'gamma': 0}
# cv results {'map': 0.76437366666666673, 'gamma': 0}
# cv results {'map': 0.76437366666666673, 'gamma': 0}
# cv results {'map': 0.76437366666666673, 'gamma': 0}
# Process PoolWorker-2:
# Process PoolWorker-3:
# Process PoolWorker-4:
# Process PoolWorker-1:
# Process PoolWorker-5:
# Traceback (most recent call last):
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
# Traceback (most recent call last):
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
# Traceback (most recent call last):
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#     self.run()
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#     self.run()
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 102, in worker
#     self._target(*self._args, **self._kwargs)
#     self.run()
#     self._target(*self._args, **self._kwargs)
# Process PoolWorker-7:
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 102, in worker
# Traceback (most recent call last):
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 102, in worker
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 102, in worker
#     task = get()
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
#     task = get()
#     task = get()
#     self._target(*self._args, **self._kwargs)
#     self.run()
#   File "/usr/lib/python2.7/multiprocessing/queues.py", line 374, in get
#     task = get()
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 102, in worker
#   File "/usr/lib/python2.7/multiprocessing/queues.py", line 376, in get
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python2.7/multiprocessing/queues.py", line 374, in get
#     racquire()
#     task = get()
#     racquire()
# KeyboardInterrupt
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 113, in worker
#   File "/usr/lib/python2.7/multiprocessing/queues.py", line 376, in get
#     return recv()
# KeyboardInterrupt
# KeyboardInterrupt
#     return recv()
#     result = (True, func(*args, **kwds))
# KeyboardInterrupt
#   File "/usr/lib/python2.7/multiprocessing/queues.py", line 374, in get
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 65, in mapstar
#     racquire()
#     return map(*args)
#   File "grid_search.py", line 144, in get_map_of_xgb
#     early_stopping_rounds = 20, feval = map3eval, maximize = True)
#   File "/usr/local/lib/python2.7/dist-packages/xgboost-0.4-py2.7.egg/xgboost/training.py", line 400, in cv
# KeyboardInterrupt
#     fold.update(i, obj)
#   File "/usr/local/lib/python2.7/dist-packages/xgboost-0.4-py2.7.egg/xgboost/training.py", line 219, in update
#     self.bst.update(self.dtrain, iteration, fobj)
#   File "/usr/local/lib/python2.7/dist-packages/xgboost-0.4-py2.7.egg/xgboost/core.py", line 806, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle, iteration, dtrain.handle))
# KeyboardInterrupt
# Process PoolWorker-6:
# Traceback (most recent call last):
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 113, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 65, in mapstar
#     return map(*args)
#   File "grid_search.py", line 144, in get_map_of_xgb
#     early_stopping_rounds = 20, feval = map3eval, maximize = True)
#   File "/usr/local/lib/python2.7/dist-packages/xgboost-0.4-py2.7.egg/xgboost/training.py", line 400, in cv
#     fold.update(i, obj)
#   File "/usr/local/lib/python2.7/dist-packages/xgboost-0.4-py2.7.egg/xgboost/training.py", line 219, in update
#     self.bst.update(self.dtrain, iteration, fobj)
#   File "/usr/local/lib/python2.7/dist-packages/xgboost-0.4-py2.7.egg/xgboost/core.py", line 806, in update
#     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle, iteration, dtrain.handle))
# KeyboardInterrupt
# Process PoolWorker-8:
# Traceback (most recent call last):
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 113, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 65, in mapstar
#     return map(*args)
#   File "grid_search.py", line 144, in get_map_of_xgb
#     early_stopping_rounds = 20, feval = map3eval, maximize = True)
#   File "/usr/local/lib/python2.7/dist-packages/xgboost-0.4-py2.7.egg/xgboost/training.py", line 401, in cv
#     res = aggcv([f.eval(i, feval) for f in cvfolds])
#   File "/usr/local/lib/python2.7/dist-packages/xgboost-0.4-py2.7.egg/xgboost/training.py", line 223, in eval
#     return self.bst.eval_set(self.watchlist, iteration, feval)
#   File "/usr/local/lib/python2.7/dist-packages/xgboost-0.4-py2.7.egg/xgboost/core.py", line 872, in eval_set
#     feval_ret = feval(self.predict(dmat), dmat)
#   File "grid_search.py", line 73, in map3eval
#     predicted = preds.argsort(axis=1)[:,-np.arange(1,4)]
# KeyboardInterrupt
# Process PoolWorker-12:
# Process PoolWorker-15:
# Process PoolWorker-11:
# Process PoolWorker-14:
# Process PoolWorker-9:
# Process PoolWorker-16:
# Process PoolWorker-13:
# Process PoolWorker-10:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#     self.run()
#     self.run()
#     self.run()
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self.run()
#     self.run()
#     self.run()
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 102, in worker
#     self._target(*self._args, **self._kwargs)
#     self._target(*self._args, **self._kwargs)
#     self._target(*self._args, **self._kwargs)
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 102, in worker
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 102, in worker
#     task = get()
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 102, in worker
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 102, in worker
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 102, in worker
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 102, in worker
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 102, in worker
#     task = get()
#     task = get()
#   File "/usr/lib/python2.7/multiprocessing/queues.py", line 376, in get
#     task = get()
#     task = get()
#     task = get()
#   File "/usr/lib/python2.7/multiprocessing/queues.py", line 374, in get
#     task = get()
#   File "/usr/lib/python2.7/multiprocessing/queues.py", line 374, in get
#     return recv()
#   File "/usr/lib/python2.7/multiprocessing/queues.py", line 374, in get
#   File "/usr/lib/python2.7/multiprocessing/queues.py", line 374, in get
#   File "/usr/lib/python2.7/multiprocessing/queues.py", line 374, in get
#     racquire()
#   File "/usr/lib/python2.7/multiprocessing/queues.py", line 376, in get
#     task = get()
# KeyboardInterrupt
#     racquire()
#     racquire()
#     racquire()
#     racquire()
#     return recv()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/usr/lib/python2.7/multiprocessing/queues.py", line 374, in get
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#     racquire()
# KeyboardInterrupt
# Process PoolWorker-24:
# Process PoolWorker-18:
# Process PoolWorker-17:
# Process PoolWorker-22:
# Process PoolWorker-21:
# Process PoolWorker-23:
# Process PoolWorker-20:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#     self.run()
#     self.run()
#     self.run()
#     self.run()
#     self.run()
#     self.run()
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self._target(*self._args, **self._kwargs)
#     self._target(*self._args, **self._kwargs)
#     self._target(*self._args, **self._kwargs)
#     self._target(*self._args, **self._kwargs)
#     self._target(*self._args, **self._kwargs)
#     self._target(*self._args, **self._kwargs)
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 102, in worker
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 102, in worker
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 102, in worker
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 102, in worker
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 102, in worker
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 102, in worker
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 102, in worker
#     task = get()
#     task = get()
#     task = get()
#     task = get()
#     task = get()
#     task = get()
#     task = get()
#   File "/usr/lib/python2.7/multiprocessing/queues.py", line 374, in get
#   File "/usr/lib/python2.7/multiprocessing/queues.py", line 376, in get
#   File "/usr/lib/python2.7/multiprocessing/queues.py", line 374, in get
#   File "/usr/lib/python2.7/multiprocessing/queues.py", line 374, in get
#   File "/usr/lib/python2.7/multiprocessing/queues.py", line 374, in get
#   File "/usr/lib/python2.7/multiprocessing/queues.py", line 376, in get
#   File "/usr/lib/python2.7/multiprocessing/queues.py", line 374, in get
#     racquire()
#     return recv()
#     racquire()
#     racquire()
#     racquire()
#     return recv()
# KeyboardInterrupt
#     racquire()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt

# %%
try:
    result2 = gs.grid_search_xgb(param_range2)
except Exception, e:
    print e
    print traceback.format_exc()
try:
    result3 = gs.grid_search_xgb(param_range3)
except Exception, e:
    print e
    print traceback.format_exc()
try:
    result4 = gs.grid_search_xgb(param_range4)
except Exception, e:
    print e
    print traceback.format_exc()
try:
    result5 = gs.grid_search_xgb(param_range5)
except Exception, e:
    print e
    print traceback.format_exc()
# Out:
# cv results {'map': 0.76262099999999988, 'gamma': 0.2}
# cv results {'map': 0.76303866666666664, 'gamma': 0.23}
# cv results {'map': 0.76317800000000002, 'gamma': 0.29}
# cv results {'map': 0.76303900000000002, 'gamma': 0.26}
# cv results {'map': 0.76303900000000002, 'gamma': 0.35}
# cv results {'map': 0.76283000000000001, 'gamma': 0.38}
# cv results {'map': 0.76324766666666666, 'gamma': 0.32}
# top map results [{'map': 0.76324766666666666, 'gamma': 0.32}, {'map': 0.76317800000000002, 'gamma': 0.29}, {'map': 0.76303900000000002, 'gamma': 0.26}]
