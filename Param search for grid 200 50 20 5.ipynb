# %%
cd scripts
# Out:
# /home/ubuntu/facebook/scripts

# %%
import itertools
from multiprocessing import Pool
import numpy as np
#Import libraries:
import pandas as pd
import numpy as np
from sklearn.ensemble import GradientBoostingClassifier  #GBM algorithm
from sklearn import cross_validation, metrics   #Additional scklearn functions
from sklearn.grid_search import GridSearchCV   #Perforing grid search

import matplotlib.pylab as plt
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 12, 4

from sklearn.cross_validation import train_test_split
import pickle

from sklearn.preprocessing import LabelEncoder

import xgboost as xgb

import traceback
import grid_generation as grid

# %%
params_range = {'a': range(1, 5),
          'b': range(6, 9)}

def transform_x(X, x_transformer = None):
    """
    X = [[x, y, a, t]]
    """
    fw = [500., 1000., 4., 3., 2., 10., 10.]
    minute_v = X[:, 3]%60
    hour_v = X[:, 3]//60
    weekday_v = hour_v//24
    month_v = weekday_v//30
    year_v = (weekday_v//365 + 1)*fw[5]
    hour_v = ((hour_v%24 + 1) + minute_v/60.0)*fw[2]
    hour_v_2 = (X[:, 3]%(60*60*24))//(60*60*2)
    hour_v_3 = (X[:, 3]%(60*60*24))//(60*60*3)
    hour_v_4 = (X[:, 3]%(60*60*24))//(60*60*4)
    hour_v_6 = (X[:, 3]%(60*60*24))//(60*60*6)
    hour_v_8 = (X[:, 3]%(60*60*24))//(60*60*8)
    weekday_v = (weekday_v%7 + 1)*fw[3]
    month_v = (month_v%12 +1)*fw[4]
    accuracy_v = np.log10(X[:, 2])*fw[6]
    x_v = X[:, 0]*fw[0]
    y_v = X[:, 1]*fw[1]
    return np.hstack((x_v.reshape(-1, 1),
                     y_v.reshape(-1, 1),
                     accuracy_v.reshape(-1, 1),
                     hour_v.reshape(-1, 1),
                     hour_v_2.reshape(-1, 1),
                     hour_v_3.reshape(-1, 1),
                     hour_v_4.reshape(-1, 1),
                     hour_v_6.reshape(-1, 1),
                     hour_v_8.reshape(-1, 1),
                     weekday_v.reshape(-1, 1),
                     month_v.reshape(-1, 1),
                     year_v.reshape(-1, 1)))

def transform_y(y, y_transformer = None):
    """
    place_ids to encoded array
    """
    y = y.astype(int)
    if y_transformer == None:
        label_encoder = LabelEncoder()
        label_encoder.fit(y)
        y_transformer = {'encoder': label_encoder}
    new_y = y_transformer['encoder'].transform(y).reshape(-1, 1)
    return (new_y, y_transformer)

def map3eval(preds, dtrain):
    actual = dtrain.get_label()
    predicted = preds.argsort(axis=1)[:,-np.arange(1,4)]
    metric = 0.
    for i in range(3):
        metric += np.sum(actual==predicted[:,i])/(i+1)
    metric /= actual.shape[0]
    return 'MAP@3', metric

def load_data(m, n):
    f = g.getGridFile(m, n)
    return np.loadtxt(f, delimiter = ',')

def get_preds(probs, encoder):
    return encoder.inverse_transform(np.argsort(probs, axis = 1)[:, ::-1][:, :3])


def get_dtrain_enc(m, n):
    data = load_data(m, n)
    M = g.M

    mask = np.array(map(lambda x: M[m][n][x] > 3, data[:, 5]))
    train = data[mask, :]
    print data.shape, "data_shape"


    X = transform_x(train[:, (1, 2, 3, 4)])
    y, enc = transform_y(train[:, 5])
    print X.shape, "X shape"
    print y.shape, "y shape"
    print len(enc['encoder'].classes_), "no of classes"

    dtrain = xgb.DMatrix(X, label=np.ravel(y))
    return (dtrain, enc)


orig_params = {
            'silent': 0,
            'nthread': 8,
            'eta': 0.1,
            'objective': 'multi:softprob',
            'max_depth': 8,
            'min_child_weight': 5,
            'gamma': 0.32,
            'subsample': 0.9,
            'colsample_bytree': 0.7,
            'scale_pos_weight': 1
            }

X = 200
Y = 50
xd = 20
yd = 5
rx = 5
ry = 10
xD = rx*X
yD = ry*Y
XX = 10000
YY = 10000

eps = 0.001

m = XX/X
n = YY/Y

M = XX/xD
N = YY/yD


g = grid.Grid(X = 200, Y = 50, xd = 20, yd = 5, pref = 'grid')
g.generateCardinalityMatrix()

tup = lambda t: list(itertools.izip(itertools.repeat(t[0]), t[1]))

def get_list_of_params(params_range):
    pr = list(map(tup, params_range.items()))
    pro = map(dict, list(itertools.product(*pr)))
    return pro


def grid_search_xgb(params_range_dict):
    grid_params_list = get_list_of_params(params_range_dict)
    p = Pool(2)
    maps = p.map(get_map_of_xgb, grid_params_list)
    p.close()
    p.join()
    sorted_maps = sorted(maps, cmp = lambda x, y: cmp(x['map'], y['map']), reverse = True)
    print "top map results", sorted_maps[:3]
    return sorted_maps

def get_map_of_xgb(grid_param):
    cv_params = dict(orig_params)
    num_class = {'num_class': len(enc['encoder'].classes_)}
    cv_params.update(num_class)
    cv_params.update(grid_param)
    # print orig_params, grid_param
    temp_cv = xgb.cv(cv_params, dtrain, num_boost_round = 5,
             early_stopping_rounds = 20, feval = map3eval, maximize = True)
    temp_map = temp_cv['test-MAP@3-mean'][temp_cv.shape[0]-1]
    grid_param['map'] = temp_map
    # print "cv results", grid_param
    return grid_param

# %%
#m, n = (12, 50) (37, 50) (12, 150) (37, 150)
#dtrain, enc = get_dtrain_enc(12, 50)
param_range1 = {
    'max_depth': range(2, 7, 1),
    'min_child_weight': range(1, 7, 1)
}

param_range2 = {
    'gamma': [i/10.0 for i in range(0, 6)]
}

param_range3 = {
    'subsample': [i/100.0 for i in range(55, 100, 5)],
    'colsample_bytree': [i/100.0 for i in range(55, 100, 5)]
}

param_range4 = {
    'max_delta_step': range(0, 20)
}

param_range5 = {
 'alpha':[0, 1e-5, 0.001, 0.005, 0.01, 0.05, 0.1]
}

# %%
orig_params = {
            'silent': 0,
            'nthread': 4,
            'eta': 0.1,
            'objective': 'multi:softprob',
            'max_depth': 8,
            'min_child_weight': 5,
            'gamma': 0.32,
            'subsample': 0.9,
            'colsample_bytree': 0.7,
            'scale_pos_weight': 1
}
print "~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~"

        
dtrain, enc = get_dtrain_enc(12, 40)
        
for param_range in [param_range1, param_range2, param_range3, param_range4]:
    result = None
    try:
        result = grid_search_xgb(param_range)
    except Exception, e:
        print e
        print traceback.format_exc()
        
    if result != None:
        temp_param = result[0]
        del(temp_param['map'])
        orig_params.update(temp_param)

# %%
try:
    result1 = grid_search_xgb(param_range1)
except Exception, e:
    print e
    print traceback.format_exc()
try:
    result2 = grid_search_xgb(param_range2)
except Exception, e:
    print e
    print traceback.format_exc()
try:
    result3 = grid_search_xgb(param_range3)
except Exception, e:
    print e
    print traceback.format_exc()
try:
    result4 = grid_search_xgb(param_range4)
except Exception, e:
    print e
    print traceback.format_exc()
# Out:
# cv results {'map': 0.63885199999999998, 'max_depth': 3, 'min_child_weight': 5}
# cv results {'map': 0.63796900000000001, 'max_depth': 5, 'min_child_weight': 5}
# cv results {'map': 0.64238433333333333, 'max_depth': 3, 'min_child_weight': 1}
# cv results {'map': 0.64459166666666656, 'max_depth': 5, 'min_child_weight': 1}
# cv results {'map': 0.63642399999999999, 'max_depth': 3, 'min_child_weight': 7}
# cv results {'map': 0.63708633333333331, 'max_depth': 5, 'min_child_weight': 7}
# cv results {'map': 0.64150099999999999, 'max_depth': 3, 'min_child_weight': 3}
# cv results {'map': 0.639073, 'max_depth': 5, 'min_child_weight': 3}
# cv results {'map': 0.64128066666666672, 'max_depth': 7, 'min_child_weight': 1}
# cv results {'map': 0.64061800000000002, 'max_depth': 7, 'min_child_weight': 5}
# cv results {'map': 0.64061800000000002, 'max_depth': 9, 'min_child_weight': 5}
# cv results {'map': 0.64083866666666667, 'max_depth': 9, 'min_child_weight': 1}
# cv results {'map': 0.63730699999999996, 'max_depth': 7, 'min_child_weight': 7}
# cv results {'map': 0.63973533333333332, 'max_depth': 7, 'min_child_weight': 3}
# cv results {'map': 0.63708600000000004, 'max_depth': 9, 'min_child_weight': 7}
# cv results {'map': 0.63951400000000003, 'max_depth': 9, 'min_child_weight': 3}
# cv results {'map': 0.6406183333333334, 'max_depth': 11, 'min_child_weight': 5}
# cv results {'map': 0.64017666666666662, 'max_depth': 11, 'min_child_weight': 1}
# cv results {'map': 0.64083866666666667, 'max_depth': 13, 'min_child_weight': 1}
# cv results {'map': 0.63774833333333325, 'max_depth': 11, 'min_child_weight': 7}
# cv results {'map': 0.64039766666666675, 'max_depth': 13, 'min_child_weight': 5}
# cv results {'map': 0.64039699999999999, 'max_depth': 11, 'min_child_weight': 3}
# cv results {'map': 0.63907266666666673, 'max_depth': 13, 'min_child_weight': 3}
# cv results {'map': 0.63885200000000009, 'max_depth': 13, 'min_child_weight': 7}
# top map results [{'map': 0.64459166666666656, 'max_depth': 5, 'min_child_weight': 1}, {'map': 0.64238433333333333, 'max_depth': 3, 'min_child_weight': 1}, {'map': 0.64150099999999999, 'max_depth': 3, 'min_child_weight': 3}]
# cv results {'map': 0.639073, 'gamma': 0.3}
# cv results {'map': 0.6395143333333333, 'gamma': 0.0}
# cv results {'map': 0.63951466666666668, 'gamma': 0.2}
# cv results {'map': 0.63951466666666668, 'gamma': 0.1}
# cv results {'map': 0.63973533333333332, 'gamma': 0.4}
# cv results {'map': 0.64017666666666662, 'gamma': 0.5}
# top map results [{'map': 0.64017666666666662, 'gamma': 0.5}, {'map': 0.63973533333333332, 'gamma': 0.4}, {'map': 0.63951466666666668, 'gamma': 0.1}]
# cv results {'scale_pos_weight': 4, 'map': 0.6386316666666666}
# cv results {'scale_pos_weight': 2, 'map': 0.6386316666666666}
# cv results {'scale_pos_weight': 3, 'map': 0.6386316666666666}
# cv results {'scale_pos_weight': 1, 'map': 0.6386316666666666}
# cv results {'scale_pos_weight': 5, 'map': 0.6386316666666666}
# cv results {'scale_pos_weight': 7, 'map': 0.6386316666666666}
# cv results {'scale_pos_weight': 6, 'map': 0.6386316666666666}
# cv results {'scale_pos_weight': 8, 'map': 0.6386316666666666}
# cv results {'scale_pos_weight': 9, 'map': 0.6386316666666666}
# top map results [{'scale_pos_weight': 1, 'map': 0.6386316666666666}, {'scale_pos_weight': 2, 'map': 0.6386316666666666}, {'scale_pos_weight': 3, 'map': 0.6386316666666666}]
# cv results {'subsample': 0.6, 'colsample_bytree': 0.7, 'map': 0.63774866666666663}
# cv results {'subsample': 0.65, 'colsample_bytree': 0.55, 'map': 0.63708600000000004}
# cv results {'subsample': 0.55, 'colsample_bytree': 0.55, 'map': 0.63554066666666664}
# cv results {'subsample': 0.55, 'colsample_bytree': 0.85, 'map': 0.63465766666666668}
# cv results {'subsample': 0.6, 'colsample_bytree': 0.75, 'map': 0.63686533333333328}
# cv results {'subsample': 0.65, 'colsample_bytree': 0.6, 'map': 0.63973499999999994}
# cv results {'subsample': 0.55, 'colsample_bytree': 0.6, 'map': 0.63465766666666668}
# cv results {'subsample': 0.55, 'colsample_bytree': 0.9, 'map': 0.63465766666666668}
# cv results {'subsample': 0.6, 'colsample_bytree': 0.8, 'map': 0.63686533333333328}
# cv results {'subsample': 0.65, 'colsample_bytree': 0.65, 'map': 0.63973499999999994}
# cv results {'subsample': 0.55, 'colsample_bytree': 0.65, 'map': 0.63465766666666668}
# cv results {'subsample': 0.55, 'colsample_bytree': 0.95, 'map': 0.63642366666666672}
# cv results {'subsample': 0.65, 'colsample_bytree': 0.7, 'map': 0.64128066666666672}
# cv results {'subsample': 0.6, 'colsample_bytree': 0.85, 'map': 0.63333366666666668}
# cv results {'subsample': 0.55, 'colsample_bytree': 0.7, 'map': 0.63664466666666664}
# cv results {'subsample': 0.6, 'colsample_bytree': 0.55, 'map': 0.63841066666666668}
# cv results {'subsample': 0.65, 'colsample_bytree': 0.75, 'map': 0.63686533333333328}
# cv results {'subsample': 0.6, 'colsample_bytree': 0.9, 'map': 0.63333366666666668}
# cv results {'subsample': 0.55, 'colsample_bytree': 0.75, 'map': 0.63554100000000002}
# cv results {'subsample': 0.6, 'colsample_bytree': 0.6, 'map': 0.6348786666666667}
# cv results {'subsample': 0.65, 'colsample_bytree': 0.8, 'map': 0.63686533333333328}
# cv results {'subsample': 0.6, 'colsample_bytree': 0.95, 'map': 0.63443700000000003}
# cv results {'subsample': 0.55, 'colsample_bytree': 0.8, 'map': 0.63554100000000002}
# cv results {'subsample': 0.6, 'colsample_bytree': 0.65, 'map': 0.6348786666666667}
# cv results {'subsample': 0.7, 'colsample_bytree': 0.7, 'map': 0.64128033333333334}
# cv results {'subsample': 0.65, 'colsample_bytree': 0.85, 'map': 0.63796933333333328}
# cv results {'subsample': 0.75, 'colsample_bytree': 0.55, 'map': 0.63951433333333341}
# cv results {'subsample': 0.75, 'colsample_bytree': 0.85, 'map': 0.63907299999999989}
# cv results {'subsample': 0.75, 'colsample_bytree': 0.6, 'map': 0.64083900000000005}
# cv results {'subsample': 0.7, 'colsample_bytree': 0.75, 'map': 0.6399556666666667}
# cv results {'subsample': 0.75, 'colsample_bytree': 0.9, 'map': 0.63907299999999989}
# cv results {'subsample': 0.65, 'colsample_bytree': 0.9, 'map': 0.63796933333333328}
# cv results {'subsample': 0.75, 'colsample_bytree': 0.65, 'map': 0.64083900000000005}
# cv results {'subsample': 0.7, 'colsample_bytree': 0.8, 'map': 0.6399556666666667}
# cv results {'subsample': 0.65, 'colsample_bytree': 0.95, 'map': 0.63686533333333328}
# cv results {'subsample': 0.75, 'colsample_bytree': 0.95, 'map': 0.63885200000000009}
# cv results {'subsample': 0.75, 'colsample_bytree': 0.7, 'map': 0.6386316666666666}
# cv results {'subsample': 0.7, 'colsample_bytree': 0.85, 'map': 0.64017666666666662}
# cv results {'subsample': 0.7, 'colsample_bytree': 0.55, 'map': 0.63951433333333341}
# cv results {'subsample': 0.8, 'colsample_bytree': 0.55, 'map': 0.63995600000000008}
# cv results {'subsample': 0.75, 'colsample_bytree': 0.75, 'map': 0.63929366666666665}
# cv results {'subsample': 0.7, 'colsample_bytree': 0.9, 'map': 0.64017666666666662}
# cv results {'subsample': 0.8, 'colsample_bytree': 0.6, 'map': 0.64127999999999996}
# cv results {'subsample': 0.7, 'colsample_bytree': 0.6, 'map': 0.64017666666666662}
# cv results {'subsample': 0.75, 'colsample_bytree': 0.8, 'map': 0.63929366666666665}
# cv results {'subsample': 0.7, 'colsample_bytree': 0.95, 'map': 0.63951433333333341}
# cv results {'subsample': 0.8, 'colsample_bytree': 0.65, 'map': 0.64127999999999996}
# cv results {'subsample': 0.8, 'colsample_bytree': 0.7, 'map': 0.6395143333333333}
# cv results {'subsample': 0.7, 'colsample_bytree': 0.65, 'map': 0.64017666666666662}
# cv results {'subsample': 0.8, 'colsample_bytree': 0.75, 'map': 0.63885199999999998}
# cv results {'subsample': 0.85, 'colsample_bytree': 0.85, 'map': 0.6406183333333334}
# cv results {'subsample': 0.85, 'colsample_bytree': 0.55, 'map': 0.63951433333333341}
# cv results {'subsample': 0.9, 'colsample_bytree': 0.7, 'map': 0.6386316666666666}
# cv results {'subsample': 0.8, 'colsample_bytree': 0.8, 'map': 0.63885199999999998}
# cv results {'subsample': 0.85, 'colsample_bytree': 0.9, 'map': 0.6406183333333334}
# cv results {'subsample': 0.9, 'colsample_bytree': 0.75, 'map': 0.63863133333333344}
# cv results {'subsample': 0.85, 'colsample_bytree': 0.6, 'map': 0.64039733333333337}
# cv results {'subsample': 0.85, 'colsample_bytree': 0.95, 'map': 0.63929366666666665}
# cv results {'subsample': 0.8, 'colsample_bytree': 0.85, 'map': 0.64061833333333329}
# cv results {'subsample': 0.9, 'colsample_bytree': 0.8, 'map': 0.63863133333333344}
# cv results {'subsample': 0.85, 'colsample_bytree': 0.65, 'map': 0.64039733333333337}
# cv results {'subsample': 0.9, 'colsample_bytree': 0.55, 'map': 0.63929366666666665}
# cv results {'subsample': 0.9, 'colsample_bytree': 0.85, 'map': 0.64039733333333337}
# cv results {'subsample': 0.85, 'colsample_bytree': 0.7, 'map': 0.64039733333333337}
# cv results {'subsample': 0.8, 'colsample_bytree': 0.9, 'map': 0.64061833333333329}
# cv results {'subsample': 0.85, 'colsample_bytree': 0.75, 'map': 0.63885233333333336}
# cv results {'subsample': 0.9, 'colsample_bytree': 0.6, 'map': 0.64128033333333334}
# cv results {'subsample': 0.9, 'colsample_bytree': 0.9, 'map': 0.64039733333333337}
# cv results {'subsample': 0.8, 'colsample_bytree': 0.95, 'map': 0.63973500000000005}
# cv results {'subsample': 0.85, 'colsample_bytree': 0.8, 'map': 0.63885233333333336}
# cv results {'subsample': 0.9, 'colsample_bytree': 0.95, 'map': 0.63995600000000008}
# cv results {'subsample': 0.9, 'colsample_bytree': 0.65, 'map': 0.64128033333333334}
# cv results {'subsample': 0.95, 'colsample_bytree': 0.55, 'map': 0.64525399999999988}
# cv results {'subsample': 0.95, 'colsample_bytree': 0.85, 'map': 0.64017666666666662}
# cv results {'subsample': 0.95, 'colsample_bytree': 0.6, 'map': 0.64415033333333327}
# cv results {'subsample': 0.95, 'colsample_bytree': 0.9, 'map': 0.64017666666666662}
# cv results {'subsample': 0.95, 'colsample_bytree': 0.65, 'map': 0.64415033333333327}
# cv results {'subsample': 0.95, 'colsample_bytree': 0.95, 'map': 0.64039733333333337}
# cv results {'subsample': 0.95, 'colsample_bytree': 0.7, 'map': 0.64150133333333337}
# cv results {'subsample': 0.95, 'colsample_bytree': 0.75, 'map': 0.64260499999999998}
# cv results {'subsample': 0.95, 'colsample_bytree': 0.8, 'map': 0.64260499999999998}
# top map results [{'subsample': 0.95, 'colsample_bytree': 0.55, 'map': 0.64525399999999988}, {'subsample': 0.95, 'colsample_bytree': 0.6, 'map': 0.64415033333333327}, {'subsample': 0.95, 'colsample_bytree': 0.65, 'map': 0.64415033333333327}]
# cv results {'alpha': 0.005, 'map': 0.63929366666666665}
# cv results {'alpha': 0.001, 'map': 0.63907300000000011}
# cv results {'alpha': 1e-05, 'map': 0.6386316666666666}
# cv results {'alpha': 0, 'map': 0.6386316666666666}
# cv results {'alpha': 0.05, 'map': 0.63951433333333341}
# cv results {'alpha': 0.01, 'map': 0.6395143333333333}
# cv results {'alpha': 0.1, 'map': 0.64150099999999999}
# cv results {'alpha': 1, 'map': 0.64017666666666662}
# cv results {'alpha': 100, 'map': 0.36026466666666668}
# top map results [{'alpha': 0.1, 'map': 0.64150099999999999}, {'alpha': 1, 'map': 0.64017666666666662}, {'alpha': 0.05, 'map': 0.63951433333333341}]

# %%
#m, n = (12, 50) (37, 50) (12, 150) (37, 150)
dtrain, enc = get_dtrain_enc(37, 50)
try:
    result1 = grid_search_xgb(param_range1)
except Exception, e:
    print e
    print traceback.format_exc()
try:
    result2 = grid_search_xgb(param_range2)
except Exception, e:
    print e
    print traceback.format_exc()
try:
    result3 = grid_search_xgb(param_range3)
except Exception, e:
    print e
    print traceback.format_exc()
try:
    result5 = grid_search_xgb(param_range5)
except Exception, e:
    print e
    print traceback.format_exc()
# Out:
# (2653, 6) data_shape
# (2373, 12) X shape
# (2373, 1) y shape
# 73 no of classes
# cv results {'map': 0.62031166666666671, 'max_depth': 3, 'min_child_weight': 5}
# cv results {'map': 0.61820466666666662, 'max_depth': 5, 'min_child_weight': 5}
# cv results {'map': 0.61736199999999997, 'max_depth': 5, 'min_child_weight': 1}
# cv results {'map': 0.61862633333333339, 'max_depth': 3, 'min_child_weight': 1}
# cv results {'map': 0.61651899999999993, 'max_depth': 3, 'min_child_weight': 7}
# cv results {'map': 0.61230499999999999, 'max_depth': 5, 'min_child_weight': 7}
# cv results {'map': 0.61525533333333338, 'max_depth': 3, 'min_child_weight': 3}
# cv results {'map': 0.61694066666666669, 'max_depth': 5, 'min_child_weight': 3}
# cv results {'map': 0.61820466666666662, 'max_depth': 7, 'min_child_weight': 5}
# cv results {'map': 0.61609766666666665, 'max_depth': 7, 'min_child_weight': 1}
# cv results {'map': 0.61651933333333331, 'max_depth': 9, 'min_child_weight': 5}
# cv results {'map': 0.61567666666666676, 'max_depth': 7, 'min_child_weight': 3}
# cv results {'map': 0.61272666666666664, 'max_depth': 7, 'min_child_weight': 7}
# cv results {'map': 0.61609800000000003, 'max_depth': 9, 'min_child_weight': 1}
# cv results {'map': 0.6118836666666666, 'max_depth': 9, 'min_child_weight': 7}
# cv results {'map': 0.61651899999999993, 'max_depth': 11, 'min_child_weight': 5}
# cv results {'map': 0.61399066666666668, 'max_depth': 9, 'min_child_weight': 3}
# cv results {'map': 0.61441200000000007, 'max_depth': 11, 'min_child_weight': 1}
# cv results {'map': 0.61314800000000003, 'max_depth': 13, 'min_child_weight': 1}
# cv results {'map': 0.61694066666666669, 'max_depth': 13, 'min_child_weight': 5}
# cv results {'map': 0.61399066666666668, 'max_depth': 11, 'min_child_weight': 7}
# cv results {'map': 0.61399066666666657, 'max_depth': 11, 'min_child_weight': 3}
# cv results {'map': 0.61314766666666676, 'max_depth': 13, 'min_child_weight': 7}
# cv results {'map': 0.61272633333333326, 'max_depth': 13, 'min_child_weight': 3}
# top map results [{'map': 0.62031166666666671, 'max_depth': 3, 'min_child_weight': 5}, {'map': 0.61862633333333339, 'max_depth': 3, 'min_child_weight': 1}, {'map': 0.61820466666666662, 'max_depth': 5, 'min_child_weight': 5}]
# cv results {'map': 0.61651933333333331, 'gamma': 0.2}
# cv results {'map': 0.61736199999999997, 'gamma': 0.1}
# cv results {'map': 0.61651899999999993, 'gamma': 0.3}
# cv results {'map': 0.61862600000000001, 'gamma': 0.0}
# cv results {'map': 0.61778333333333346, 'gamma': 0.4}
# cv results {'map': 0.61946899999999994, 'gamma': 0.5}
# top map results [{'map': 0.61946899999999994, 'gamma': 0.5}, {'map': 0.61862600000000001, 'gamma': 0.0}, {'map': 0.61778333333333346, 'gamma': 0.4}]
# cv results {'scale_pos_weight': 3, 'map': 0.61736199999999997}
# cv results {'scale_pos_weight': 1, 'map': 0.61736199999999997}
# cv results {'scale_pos_weight': 4, 'map': 0.61736199999999997}
# cv results {'scale_pos_weight': 2, 'map': 0.61736199999999997}
# cv results {'scale_pos_weight': 5, 'map': 0.61736199999999997}
# cv results {'scale_pos_weight': 6, 'map': 0.61736199999999997}
# cv results {'scale_pos_weight': 7, 'map': 0.61736199999999997}
# cv results {'scale_pos_weight': 8, 'map': 0.61736199999999997}
# cv results {'scale_pos_weight': 9, 'map': 0.61736199999999997}
# top map results [{'scale_pos_weight': 1, 'map': 0.61736199999999997}, {'scale_pos_weight': 2, 'map': 0.61736199999999997}, {'scale_pos_weight': 3, 'map': 0.61736199999999997}]
# cv results {'alpha': 1e-05, 'map': 0.61567666666666665}
# cv results {'alpha': 0, 'map': 0.61736199999999997}
# cv results {'alpha': 0.005, 'map': 0.61862600000000001}
# cv results {'alpha': 0.001, 'map': 0.61694066666666669}
# cv results {'alpha': 0.1, 'map': 0.61946900000000005}
# cv results {'alpha': 0.01, 'map': 0.61820466666666674}
# cv results {'alpha': 0.05, 'map': 0.61862633333333328}
# cv results {'alpha': 1, 'map': 0.61651933333333331}
# cv results {'alpha': 100, 'map': 0.34260433333333334}
# top map results [{'alpha': 0.1, 'map': 0.61946900000000005}, {'alpha': 0.05, 'map': 0.61862633333333328}, {'alpha': 0.005, 'map': 0.61862600000000001}]

# %%
#m, n = (12, 50) (37, 50) (12, 150) (37, 150)
dtrain, enc = get_dtrain_enc(12, 150)
try:
    result1 = grid_search_xgb(param_range1)
except Exception, e:
    print e
    print traceback.format_exc()
try:
    result2 = grid_search_xgb(param_range2)
except Exception, e:
    print e
    print traceback.format_exc()
try:
    result3 = grid_search_xgb(param_range3)
except Exception, e:
    print e
    print traceback.format_exc()
try:
    result5 = grid_search_xgb(param_range5)
except Exception, e:
    print e
    print traceback.format_exc()
# Out:
# (4329, 6) data_shape
# (4085, 12) X shape
# (4085, 1) y shape
# 94 no of classes
# cv results {'map': 0.60739633333333332, 'max_depth': 5, 'min_child_weight': 5}
# cv results {'map': 0.60960099999999995, 'max_depth': 5, 'min_child_weight': 1}
# cv results {'map': 0.60837599999999992, 'max_depth': 3, 'min_child_weight': 5}
# cv results {'map': 0.60764166666666664, 'max_depth': 3, 'min_child_weight': 1}
# cv results {'map': 0.60764133333333337, 'max_depth': 5, 'min_child_weight': 7}
# cv results {'map': 0.60862099999999997, 'max_depth': 3, 'min_child_weight': 7}
# cv results {'map': 0.60690666666666671, 'max_depth': 5, 'min_child_weight': 3}
# cv results {'map': 0.60494700000000001, 'max_depth': 3, 'min_child_weight': 3}
# cv results {'map': 0.6083763333333333, 'max_depth': 7, 'min_child_weight': 5}
# cv results {'map': 0.60788633333333342, 'max_depth': 7, 'min_child_weight': 1}
# cv results {'map': 0.60788633333333342, 'max_depth': 9, 'min_child_weight': 5}
# cv results {'map': 0.60690666666666659, 'max_depth': 9, 'min_child_weight': 1}
# cv results {'map': 0.6073966666666667, 'max_depth': 7, 'min_child_weight': 7}
# cv results {'map': 0.60617200000000004, 'max_depth': 7, 'min_child_weight': 3}
# cv results {'map': 0.60813133333333325, 'max_depth': 9, 'min_child_weight': 7}
# cv results {'map': 0.60739633333333332, 'max_depth': 11, 'min_child_weight': 1}
# cv results {'map': 0.60690666666666671, 'max_depth': 9, 'min_child_weight': 3}
# cv results {'map': 0.60396766666666668, 'max_depth': 11, 'min_child_weight': 5}
# cv results {'map': 0.6083763333333333, 'max_depth': 13, 'min_child_weight': 1}
# cv results {'map': 0.60568199999999994, 'max_depth': 11, 'min_child_weight': 3}
# cv results {'map': 0.60935566666666663, 'max_depth': 13, 'min_child_weight': 5}
# cv results {'map': 0.60788666666666658, 'max_depth': 13, 'min_child_weight': 3}
# cv results {'map': 0.6064166666666666, 'max_depth': 11, 'min_child_weight': 7}
# cv results {'map': 0.60568233333333332, 'max_depth': 13, 'min_child_weight': 7}
# top map results [{'map': 0.60960099999999995, 'max_depth': 5, 'min_child_weight': 1}, {'map': 0.60935566666666663, 'max_depth': 13, 'min_child_weight': 5}, {'map': 0.60862099999999997, 'max_depth': 3, 'min_child_weight': 7}]
# cv results {'map': 0.60813133333333336, 'gamma': 0.1}
# cv results {'map': 0.60813133333333336, 'gamma': 0.3}
# cv results {'map': 0.60715166666666676, 'gamma': 0.2}
# cv results {'map': 0.60690666666666671, 'gamma': 0.0}
# cv results {'map': 0.6083763333333333, 'gamma': 0.5}
# cv results {'map': 0.60886600000000002, 'gamma': 0.4}
# top map results [{'map': 0.60886600000000002, 'gamma': 0.4}, {'map': 0.6083763333333333, 'gamma': 0.5}, {'map': 0.60813133333333336, 'gamma': 0.1}]
# cv results {'scale_pos_weight': 4, 'map': 0.60690633333333333}
# cv results {'scale_pos_weight': 3, 'map': 0.60690633333333333}
# cv results {'scale_pos_weight': 2, 'map': 0.60690633333333333}
# cv results {'scale_pos_weight': 1, 'map': 0.60690633333333333}
# cv results {'scale_pos_weight': 5, 'map': 0.60690633333333333}
# cv results {'scale_pos_weight': 6, 'map': 0.60690633333333333}
# cv results {'scale_pos_weight': 8, 'map': 0.60690633333333333}
# cv results {'scale_pos_weight': 7, 'map': 0.60690633333333333}
# cv results {'scale_pos_weight': 9, 'map': 0.60690633333333333}
# top map results [{'scale_pos_weight': 1, 'map': 0.60690633333333333}, {'scale_pos_weight': 2, 'map': 0.60690633333333333}, {'scale_pos_weight': 3, 'map': 0.60690633333333333}]
# cv results {'alpha': 0, 'map': 0.60690633333333333}
# cv results {'alpha': 0.005, 'map': 0.60813133333333336}
# cv results {'alpha': 1e-05, 'map': 0.60690633333333333}
# cv results {'alpha': 0.001, 'map': 0.6073966666666667}
# cv results {'alpha': 0.01, 'map': 0.60935566666666674}
# cv results {'alpha': 0.1, 'map': 0.60984566666666662}
# cv results {'alpha': 0.05, 'map': 0.60494700000000001}
# cv results {'alpha': 100, 'map': 0.30859633333333331}
# cv results {'alpha': 1, 'map': 0.60813133333333325}
# top map results [{'alpha': 0.1, 'map': 0.60984566666666662}, {'alpha': 0.01, 'map': 0.60935566666666674}, {'alpha': 0.005, 'map': 0.60813133333333336}]

# %%
#m, n = (12, 50) (37, 50) (12, 150) (37, 150)
dtrain, enc = get_dtrain_enc(37, 150)
try:
    result1 = grid_search_xgb(param_range1)
except Exception, e:
    print e
    print traceback.format_exc()
try:
    result2 = grid_search_xgb(param_range2)
except Exception, e:
    print e
    print traceback.format_exc()
try:
    result3 = grid_search_xgb(param_range3)
except Exception, e:
    print e
    print traceback.format_exc()
try:
    result5 = grid_search_xgb(param_range5)
except Exception, e:
    print e
    print traceback.format_exc()
# Out:
# (3879, 6) data_shape
# (3597, 12) X shape
# (3597, 1) y shape
# 77 no of classes
# cv results {'map': 0.68529333333333342, 'max_depth': 5, 'min_child_weight': 1}
# cv results {'map': 0.68584933333333342, 'max_depth': 5, 'min_child_weight': 5}
# cv results {'map': 0.68445933333333331, 'max_depth': 3, 'min_child_weight': 5}
# cv results {'map': 0.68306933333333342, 'max_depth': 3, 'min_child_weight': 1}
# cv results {'map': 0.68640533333333342, 'gamma': 0.1}
# cv results {'map': 0.68557133333333331, 'gamma': 0.3}
# cv results {'map': 0.68723933333333331, 'gamma': 0.2}
# cv results {'map': 0.68751733333333342, 'gamma': 0.0}
# cv results {'map': 0.68668333333333331, 'gamma': 0.5}
# cv results {'map': 0.68473733333333342, 'gamma': 0.4}
# top map results [{'map': 0.68751733333333342, 'gamma': 0.0}, {'map': 0.68723933333333331, 'gamma': 0.2}, {'map': 0.68668333333333331, 'gamma': 0.5}]
# cv results {'scale_pos_weight': 1, 'map': 0.68807333333333343}
# cv results {'scale_pos_weight': 4, 'map': 0.68807333333333343}
# cv results {'scale_pos_weight': 2, 'map': 0.68807333333333343}
# cv results {'scale_pos_weight': 3, 'map': 0.68807333333333343}
# cv results {'scale_pos_weight': 5, 'map': 0.68807333333333343}
# cv results {'scale_pos_weight': 7, 'map': 0.68807333333333343}
# cv results {'scale_pos_weight': 6, 'map': 0.68807333333333343}
# cv results {'scale_pos_weight': 8, 'map': 0.68807333333333343}
# cv results {'scale_pos_weight': 9, 'map': 0.68807333333333343}
# top map results [{'scale_pos_weight': 1, 'map': 0.68807333333333343}, {'scale_pos_weight': 2, 'map': 0.68807333333333343}, {'scale_pos_weight': 3, 'map': 0.68807333333333343}]
# cv results {'alpha': 0.001, 'map': 0.68696133333333342}
# cv results {'alpha': 0, 'map': 0.68807333333333343}
# cv results {'alpha': 1e-05, 'map': 0.68807333333333343}
# cv results {'alpha': 0.005, 'map': 0.68612733333333331}
# cv results {'alpha': 0.01, 'map': 0.68779533333333331}
# cv results {'alpha': 0.05, 'map': 0.68807333333333343}
# cv results {'alpha': 100, 'map': 0.38420900000000002}
# cv results {'alpha': 0.1, 'map': 0.68696133333333342}
# cv results {'alpha': 1, 'map': 0.68418133333333342}
# top map results [{'alpha': 0, 'map': 0.68807333333333343}, {'alpha': 1e-05, 'map': 0.68807333333333343}, {'alpha': 0.05, 'map': 0.68807333333333343}]

# %%
params_dict = [[{} for nt in range(n + 1)] for mt in range(m + 1)]
param_range1 = {
    'max_depth': range(2, 4, 1),
    'min_child_weight': range(1, 3, 1)
}
for Mt in range(M):
    for Nt in range(N):
        orig_params = {
            'silent': 0,
            'nthread': 8,
            'eta': 0.1,
            'objective': 'multi:softprob',
            'max_depth': 8,
            'min_child_weight': 5,
            'gamma': 0.32,
            'subsample': 0.9,
            'colsample_bytree': 0.7,
            'scale_pos_weight': 1
            }
        print "~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~"
        print Mt, "Mt"
        print Nt, "Nt"
        x = (Mt * xD)*eps + eps
        y = (Nt * yD)*eps + eps
        print x, y
        (mt, nt) = grid.get_grids((x, y), X, Y, xd, yd)[0]
        print mt, "mt"
        print nt, "nt"
        
        dtrain, enc = get_dtrain_enc(mt, nt)
        
        for param_range in [param_range1]:#, param_range2, param_range3, param_range4]:
            result = None
            try:
                result = grid_search_xgb(param_range)
            except Exception, e:
                print e
                print traceback.format_exc()
        
            if result != None:
                temp_param = result[0]
                del(temp_param['map'])
                orig_params.update(temp_param)
        for mc in range(rx + 1):
            for nc in range(ry + 1):
                if (mt + mc) < (g.max_m + 1) and (nt + nc) < (g.max_n + 1):
                    params_dict[mt + mc][nt + nc] = dict(orig_params) 
        
        
        
        print "computed params for big grid %s, %s" %(Mt, Nt)
        print orig_params
        print "~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~"
# Out:
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 0 Mt
# 0 Nt
# 0.001 0.001
# 0 mt
# 0 nt
# (2756, 6) data_shape
# (2645, 12) X shape
# (2645, 1) y shape
# 43 no of classes
# top map results [{'map': 0.68217933333333336, 'max_depth': 3, 'min_child_weight': 1}, {'map': 0.67953066666666662, 'max_depth': 3, 'min_child_weight': 2}, {'map': 0.64093833333333328, 'max_depth': 2, 'min_child_weight': 1}]
# computed params for big grid 0, 0
# {'colsample_bytree': 0.7, 'silent': 0, 'scale_pos_weight': 1, 'nthread': 8, 'min_child_weight': 1, 'subsample': 0.9, 'eta': 0.1, 'objective': 'multi:softprob', 'max_depth': 3, 'gamma': 0.32}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 0 Mt
# 1 Nt
# 0.001 0.501
# 0 mt
# 10 nt
# (2374, 6) data_shape
# (2218, 12) X shape
# (2218, 1) y shape
# 48 no of classes
# top map results [{'map': 0.65448766666666669, 'max_depth': 3, 'min_child_weight': 2}, {'map': 0.6517816666666667, 'max_depth': 3, 'min_child_weight': 1}, {'map': 0.60893066666666662, 'max_depth': 2, 'min_child_weight': 2}]
# computed params for big grid 0, 1
# {'colsample_bytree': 0.7, 'silent': 0, 'scale_pos_weight': 1, 'nthread': 8, 'min_child_weight': 2, 'subsample': 0.9, 'eta': 0.1, 'objective': 'multi:softprob', 'max_depth': 3, 'gamma': 0.32}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 0 Mt
# 2 Nt
# 0.001 1.001
# 0 mt
# 20 nt
# (5806, 6) data_shape
# (5606, 12) X shape
# (5606, 1) y shape
# 60 no of classes
# top map results [{'map': 0.69735900000000006, 'max_depth': 3, 'min_child_weight': 1}, {'map': 0.69379000000000002, 'max_depth': 3, 'min_child_weight': 2}, {'map': 0.65649533333333332, 'max_depth': 2, 'min_child_weight': 1}]
# computed params for big grid 0, 2
# {'colsample_bytree': 0.7, 'silent': 0, 'scale_pos_weight': 1, 'nthread': 8, 'min_child_weight': 1, 'subsample': 0.9, 'eta': 0.1, 'objective': 'multi:softprob', 'max_depth': 3, 'gamma': 0.32}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 0 Mt
# 3 Nt
# 0.001 1.501
# 0 mt
# 30 nt
# (4537, 6) data_shape
# (4328, 12) X shape
# (4328, 1) y shape
# 57 no of classes
# top map results [{'map': 0.63661599999999996, 'max_depth': 3, 'min_child_weight': 1}, {'map': 0.63592233333333337, 'max_depth': 3, 'min_child_weight': 2}, {'map': 0.59500699999999995, 'max_depth': 2, 'min_child_weight': 2}]
# computed params for big grid 0, 3
# {'colsample_bytree': 0.7, 'silent': 0, 'scale_pos_weight': 1, 'nthread': 8, 'min_child_weight': 1, 'subsample': 0.9, 'eta': 0.1, 'objective': 'multi:softprob', 'max_depth': 3, 'gamma': 0.32}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 0 Mt
# 4 Nt
# 0.001 2.001
# 0 mt
# 40 nt
# (4293, 6) data_shape
# (4099, 12) X shape
# (4099, 1) y shape
# 56 no of classes
# top map results [{'map': 0.672767, 'max_depth': 3, 'min_child_weight': 1}, {'map': 0.67105899999999996, 'max_depth': 3, 'min_child_weight': 2}, {'map': 0.63225966666666678, 'max_depth': 2, 'min_child_weight': 1}]
# computed params for big grid 0, 4
# {'colsample_bytree': 0.7, 'silent': 0, 'scale_pos_weight': 1, 'nthread': 8, 'min_child_weight': 1, 'subsample': 0.9, 'eta': 0.1, 'objective': 'multi:softprob', 'max_depth': 3, 'gamma': 0.32}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 0 Mt
# 5 Nt
# 0.001 2.501
# 0 mt
# 50 nt
# (2986, 6) data_shape
# (2831, 12) X shape
# (2831, 1) y shape
# 61 no of classes
# top map results [{'map': 0.58996099999999996, 'max_depth': 3, 'min_child_weight': 1}, {'map': 0.5832449999999999, 'max_depth': 3, 'min_child_weight': 2}, {'map': 0.55638033333333337, 'max_depth': 2, 'min_child_weight': 2}]
# computed params for big grid 0, 5
# {'colsample_bytree': 0.7, 'silent': 0, 'scale_pos_weight': 1, 'nthread': 8, 'min_child_weight': 1, 'subsample': 0.9, 'eta': 0.1, 'objective': 'multi:softprob', 'max_depth': 3, 'gamma': 0.32}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 0 Mt
# 6 Nt
# 0.001 3.001
# 0 mt
# 60 nt
# (2921, 6) data_shape
# (2770, 12) X shape
# (2770, 1) y shape
# 54 no of classes
# top map results [{'map': 0.61827399999999999, 'max_depth': 3, 'min_child_weight': 2}, {'map': 0.61719033333333329, 'max_depth': 3, 'min_child_weight': 1}, {'map': 0.57999266666666671, 'max_depth': 2, 'min_child_weight': 1}]
# computed params for big grid 0, 6
# {'colsample_bytree': 0.7, 'silent': 0, 'scale_pos_weight': 1, 'nthread': 8, 'min_child_weight': 2, 'subsample': 0.9, 'eta': 0.1, 'objective': 'multi:softprob', 'max_depth': 3, 'gamma': 0.32}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 0 Mt
# 7 Nt
# 0.001 3.501
# 0 mt
# 70 nt
# (4409, 6) data_shape
# (4211, 12) X shape
# (4211, 1) y shape
# 51 no of classes
# top map results [{'map': 0.67949666666666664, 'max_depth': 3, 'min_child_weight': 1}, {'map': 0.67902133333333337, 'max_depth': 3, 'min_child_weight': 2}, {'map': 0.64053233333333337, 'max_depth': 2, 'min_child_weight': 1}]
# computed params for big grid 0, 7
# {'colsample_bytree': 0.7, 'silent': 0, 'scale_pos_weight': 1, 'nthread': 8, 'min_child_weight': 1, 'subsample': 0.9, 'eta': 0.1, 'objective': 'multi:softprob', 'max_depth': 3, 'gamma': 0.32}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 0 Mt
# 8 Nt
# 0.001 4.001
# 0 mt
# 80 nt
# (4054, 6) data_shape
# (3892, 12) X shape
# (3892, 1) y shape
# 66 no of classes
# top map results [{'map': 0.63248533333333334, 'max_depth': 3, 'min_child_weight': 1}, {'map': 0.62837299999999996, 'max_depth': 3, 'min_child_weight': 2}, {'map': 0.59650499999999995, 'max_depth': 2, 'min_child_weight': 1}]
# computed params for big grid 0, 8
# {'colsample_bytree': 0.7, 'silent': 0, 'scale_pos_weight': 1, 'nthread': 8, 'min_child_weight': 1, 'subsample': 0.9, 'eta': 0.1, 'objective': 'multi:softprob', 'max_depth': 3, 'gamma': 0.32}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 0 Mt
# 9 Nt
# 0.001 4.501
# 0 mt
# 90 nt
# (2216, 6) data_shape
# (2023, 12) X shape
# (2023, 1) y shape
# 44 no of classes
# top map results [{'map': 0.72354099999999999, 'max_depth': 3, 'min_child_weight': 1}, {'map': 0.71909000000000001, 'max_depth': 3, 'min_child_weight': 2}, {'map': 0.70079166666666659, 'max_depth': 2, 'min_child_weight': 2}]
# computed params for big grid 0, 9
# {'colsample_bytree': 0.7, 'silent': 0, 'scale_pos_weight': 1, 'nthread': 8, 'min_child_weight': 1, 'subsample': 0.9, 'eta': 0.1, 'objective': 'multi:softprob', 'max_depth': 3, 'gamma': 0.32}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 0 Mt
# 10 Nt
# 0.001 5.001
# 0 mt
# 100 nt
# (2522, 6) data_shape
# (2326, 12) X shape
# (2326, 1) y shape
# 53 no of classes
# top map results [{'map': 0.69333366666666674, 'max_depth': 3, 'min_child_weight': 2}, {'map': 0.69290333333333332, 'max_depth': 3, 'min_child_weight': 1}, {'map': 0.66881733333333326, 'max_depth': 2, 'min_child_weight': 1}]
# computed params for big grid 0, 10
# {'colsample_bytree': 0.7, 'silent': 0, 'scale_pos_weight': 1, 'nthread': 8, 'min_child_weight': 2, 'subsample': 0.9, 'eta': 0.1, 'objective': 'multi:softprob', 'max_depth': 3, 'gamma': 0.32}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 0 Mt
# 11 Nt
# 0.001 5.501
# 0 mt
# 110 nt
# (3806, 6) data_shape
# (3596, 12) X shape
# (3596, 1) y shape
# 40 no of classes
# top map results [{'map': 0.71841966666666668, 'max_depth': 3, 'min_child_weight': 1}, {'map': 0.71730666666666665, 'max_depth': 3, 'min_child_weight': 2}, {'map': 0.66861433333333331, 'max_depth': 2, 'min_child_weight': 1}]
# computed params for big grid 0, 11
# {'colsample_bytree': 0.7, 'silent': 0, 'scale_pos_weight': 1, 'nthread': 8, 'min_child_weight': 1, 'subsample': 0.9, 'eta': 0.1, 'objective': 'multi:softprob', 'max_depth': 3, 'gamma': 0.32}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 0 Mt
# 12 Nt
# 0.001 6.001
# 0 mt
# 120 nt
# (2212, 6) data_shape
# (2043, 12) X shape
# (2043, 1) y shape
# 51 no of classes
# top map results [{'map': 0.62114566666666671, 'max_depth': 3, 'min_child_weight': 1}, {'map': 0.61429266666666671, 'max_depth': 3, 'min_child_weight': 2}, {'map': 0.57611333333333337, 'max_depth': 2, 'min_child_weight': 2}]
# computed params for big grid 0, 12
# {'colsample_bytree': 0.7, 'silent': 0, 'scale_pos_weight': 1, 'nthread': 8, 'min_child_weight': 1, 'subsample': 0.9, 'eta': 0.1, 'objective': 'multi:softprob', 'max_depth': 3, 'gamma': 0.32}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 0 Mt
# 13 Nt
# 0.001 6.501
# 0 mt
# 130 nt
# (4208, 6) data_shape
# (4034, 12) X shape
# (4034, 1) y shape
# 56 no of classes
# top map results [{'map': 0.74131933333333322, 'max_depth': 3, 'min_child_weight': 1}, {'map': 0.73834299999999997, 'max_depth': 3, 'min_child_weight': 2}, {'map': 0.71106133333333332, 'max_depth': 2, 'min_child_weight': 2}]
# computed params for big grid 0, 13
# {'colsample_bytree': 0.7, 'silent': 0, 'scale_pos_weight': 1, 'nthread': 8, 'min_child_weight': 1, 'subsample': 0.9, 'eta': 0.1, 'objective': 'multi:softprob', 'max_depth': 3, 'gamma': 0.32}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 0 Mt
# 14 Nt
# 0.001 7.001
# 0 mt
# 140 nt
# (2685, 6) data_shape
# (2489, 12) X shape
# (2489, 1) y shape
# 52 no of classes
# top map results [{'map': 0.58866099999999999, 'max_depth': 3, 'min_child_weight': 2}, {'map': 0.58544466666666672, 'max_depth': 3, 'min_child_weight': 1}, {'map': 0.5516686666666667, 'max_depth': 2, 'min_child_weight': 1}]
# computed params for big grid 0, 14
# {'colsample_bytree': 0.7, 'silent': 0, 'scale_pos_weight': 1, 'nthread': 8, 'min_child_weight': 2, 'subsample': 0.9, 'eta': 0.1, 'objective': 'multi:softprob', 'max_depth': 3, 'gamma': 0.32}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 0 Mt
# 15 Nt
# 0.001 7.501
# 0 mt
# 150 nt
# (1411, 6) data_shape
# (1247, 12) X shape
# (1247, 1) y shape
# 46 no of classes
# top map results [{'map': 0.6080323333333334, 'max_depth': 3, 'min_child_weight': 1}, {'map': 0.59116500000000005, 'max_depth': 3, 'min_child_weight': 2}, {'map': 0.57911633333333334, 'max_depth': 2, 'min_child_weight': 1}]
# computed params for big grid 0, 15
# {'colsample_bytree': 0.7, 'silent': 0, 'scale_pos_weight': 1, 'nthread': 8, 'min_child_weight': 1, 'subsample': 0.9, 'eta': 0.1, 'objective': 'multi:softprob', 'max_depth': 3, 'gamma': 0.32}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 0 Mt
# 16 Nt
# 0.001 8.001
# 0 mt
# 160 nt
# (2008, 6) data_shape
# (1838, 12) X shape
# (1838, 1) y shape
# 40 no of classes
# top map results [{'map': 0.69389966666666669, 'max_depth': 3, 'min_child_weight': 1}, {'map': 0.69008700000000001, 'max_depth': 3, 'min_child_weight': 2}, {'map': 0.66448833333333335, 'max_depth': 2, 'min_child_weight': 1}]
# computed params for big grid 0, 16
# {'colsample_bytree': 0.7, 'silent': 0, 'scale_pos_weight': 1, 'nthread': 8, 'min_child_weight': 1, 'subsample': 0.9, 'eta': 0.1, 'objective': 'multi:softprob', 'max_depth': 3, 'gamma': 0.32}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 0 Mt
# 17 Nt
# 0.001 8.501
# 0 mt
# 170 nt
# (2569, 6) data_shape
# (2432, 12) X shape
# (2432, 1) y shape
# 43 no of classes
# top map results [{'map': 0.73045300000000013, 'max_depth': 3, 'min_child_weight': 1}, {'map': 0.72921766666666665, 'max_depth': 3, 'min_child_weight': 2}, {'map': 0.70699566666666669, 'max_depth': 2, 'min_child_weight': 1}]
# computed params for big grid 0, 17
# {'colsample_bytree': 0.7, 'silent': 0, 'scale_pos_weight': 1, 'nthread': 8, 'min_child_weight': 1, 'subsample': 0.9, 'eta': 0.1, 'objective': 'multi:softprob', 'max_depth': 3, 'gamma': 0.32}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 0 Mt
# 18 Nt
# 0.001 9.001
# 0 mt
# 180 nt
# (2311, 6) data_shape
# (2135, 12) X shape
# (2135, 1) y shape
# 38 no of classes
# top map results [{'map': 0.72292533333333342, 'max_depth': 3, 'min_child_weight': 1}, {'map': 0.72245666666666664, 'max_depth': 3, 'min_child_weight': 2}, {'map': 0.69995300000000016, 'max_depth': 2, 'min_child_weight': 1}]
# computed params for big grid 0, 18
# {'colsample_bytree': 0.7, 'silent': 0, 'scale_pos_weight': 1, 'nthread': 8, 'min_child_weight': 1, 'subsample': 0.9, 'eta': 0.1, 'objective': 'multi:softprob', 'max_depth': 3, 'gamma': 0.32}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 0 Mt
# 19 Nt
# 0.001 9.501
# 0 mt
# 190 nt
# (4227, 6) data_shape
# (4052, 12) X shape
# (4052, 1) y shape
# 64 no of classes
# top map results [{'map': 0.63185199999999997, 'max_depth': 3, 'min_child_weight': 1}, {'map': 0.62839499999999993, 'max_depth': 3, 'min_child_weight': 2}, {'map': 0.6009876666666667, 'max_depth': 2, 'min_child_weight': 1}]
# computed params for big grid 0, 19
# {'colsample_bytree': 0.7, 'silent': 0, 'scale_pos_weight': 1, 'nthread': 8, 'min_child_weight': 1, 'subsample': 0.9, 'eta': 0.1, 'objective': 'multi:softprob', 'max_depth': 3, 'gamma': 0.32}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 1 Mt
# 0 Nt
# 1.001 0.001
# 5 mt
# 0 nt
# (2748, 6) data_shape
# (2579, 12) X shape
# (2579, 1) y shape
# 45 no of classes
# top map results [{'map': 0.65269699999999997, 'max_depth': 3, 'min_child_weight': 1}, {'map': 0.65192100000000008, 'max_depth': 3, 'min_child_weight': 2}, {'map': 0.60729533333333341, 'max_depth': 2, 'min_child_weight': 1}]
# computed params for big grid 1, 0
# {'colsample_bytree': 0.7, 'silent': 0, 'scale_pos_weight': 1, 'nthread': 8, 'min_child_weight': 1, 'subsample': 0.9, 'eta': 0.1, 'objective': 'multi:softprob', 'max_depth': 3, 'gamma': 0.32}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 1 Mt
# 1 Nt
# 1.001 0.501
# 5 mt
# 10 nt
# (2600, 6) data_shape
# (2378, 12) X shape
# (2378, 1) y shape
# 55 no of classes
# top map results [{'map': 0.69907399999999997, 'max_depth': 3, 'min_child_weight': 1}, {'map': 0.69191933333333333, 'max_depth': 3, 'min_child_weight': 2}, {'map': 0.65109400000000006, 'max_depth': 2, 'min_child_weight': 1}]
# computed params for big grid 1, 1
# {'colsample_bytree': 0.7, 'silent': 0, 'scale_pos_weight': 1, 'nthread': 8, 'min_child_weight': 1, 'subsample': 0.9, 'eta': 0.1, 'objective': 'multi:softprob', 'max_depth': 3, 'gamma': 0.32}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 1 Mt
# 2 Nt
# 1.001 1.001
# 5 mt
# 20 nt
# (8110, 6) data_shape
# (7893, 12) X shape
# (7893, 1) y shape
# 96 no of classes
# top map results [{'map': 0.57227933333333336, 'max_depth': 3, 'min_child_weight': 1}, {'map': 0.56961866666666661, 'max_depth': 3, 'min_child_weight': 2}, {'map': 0.52945666666666669, 'max_depth': 2, 'min_child_weight': 2}]
# computed params for big grid 1, 2
# {'colsample_bytree': 0.7, 'silent': 0, 'scale_pos_weight': 1, 'nthread': 8, 'min_child_weight': 1, 'subsample': 0.9, 'eta': 0.1, 'objective': 'multi:softprob', 'max_depth': 3, 'gamma': 0.32}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 1 Mt
# 3 Nt
# 1.001 1.501
# 5 mt
# 30 nt
# (3448, 6) data_shape
# (3238, 12) X shape
# (3238, 1) y shape
# 80 no of classes
# top map results [{'map': 0.56441133333333338, 'max_depth': 3, 'min_child_weight': 1}, {'map': 0.56132199999999999, 'max_depth': 3, 'min_child_weight': 2}, {'map': 0.52425099999999991, 'max_depth': 2, 'min_child_weight': 1}]
# computed params for big grid 1, 3
# {'colsample_bytree': 0.7, 'silent': 0, 'scale_pos_weight': 1, 'nthread': 8, 'min_child_weight': 1, 'subsample': 0.9, 'eta': 0.1, 'objective': 'multi:softprob', 'max_depth': 3, 'gamma': 0.32}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 1 Mt
# 4 Nt
# 1.001 2.001
# 5 mt
# 40 nt
# (4865, 6) data_shape
# (4606, 12) X shape
# (4606, 1) y shape
# 83 no of classes
# top map results [{'map': 0.65320299999999998, 'max_depth': 3, 'min_child_weight': 1}, {'map': 0.64994566666666664, 'max_depth': 3, 'min_child_weight': 2}, {'map': 0.60803499999999999, 'max_depth': 2, 'min_child_weight': 1}]
# computed params for big grid 1, 4
# {'colsample_bytree': 0.7, 'silent': 0, 'scale_pos_weight': 1, 'nthread': 8, 'min_child_weight': 1, 'subsample': 0.9, 'eta': 0.1, 'objective': 'multi:softprob', 'max_depth': 3, 'gamma': 0.32}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 1 Mt
# 5 Nt
# 1.001 2.501
# 5 mt
# 50 nt
# (3672, 6) data_shape
# (3426, 12) X shape
# (3426, 1) y shape
# 67 no of classes
# top map results [{'map': 0.6567426666666667, 'max_depth': 3, 'min_child_weight': 1}, {'map': 0.65002899999999997, 'max_depth': 3, 'min_child_weight': 2}, {'map': 0.6077056666666667, 'max_depth': 2, 'min_child_weight': 1}]
# computed params for big grid 1, 5
# {'colsample_bytree': 0.7, 'silent': 0, 'scale_pos_weight': 1, 'nthread': 8, 'min_child_weight': 1, 'subsample': 0.9, 'eta': 0.1, 'objective': 'multi:softprob', 'max_depth': 3, 'gamma': 0.32}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 1 Mt
# 6 Nt
# 1.001 3.001
# 5 mt
# 60 nt
# (3839, 6) data_shape
# (3612, 12) X shape
# (3612, 1) y shape
# 73 no of classes
# top map results [{'map': 0.61877099999999996, 'max_depth': 3, 'min_child_weight': 1}, {'map': 0.61212633333333333, 'max_depth': 3, 'min_child_weight': 2}, {'map': 0.58001133333333332, 'max_depth': 2, 'min_child_weight': 1}]
# computed params for big grid 1, 6
# {'colsample_bytree': 0.7, 'silent': 0, 'scale_pos_weight': 1, 'nthread': 8, 'min_child_weight': 1, 'subsample': 0.9, 'eta': 0.1, 'objective': 'multi:softprob', 'max_depth': 3, 'gamma': 0.32}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 1 Mt
# 7 Nt
# 1.001 3.501
# 5 mt
# 70 nt
# (4040, 6) data_shape
# (3788, 12) X shape
# (3788, 1) y shape
# 86 no of classes
# top map results [{'map': 0.57342833333333332, 'max_depth': 3, 'min_child_weight': 1}, {'map': 0.56629666666666667, 'max_depth': 3, 'min_child_weight': 2}, {'map': 0.53222366666666665, 'max_depth': 2, 'min_child_weight': 1}]
# computed params for big grid 1, 7
# {'colsample_bytree': 0.7, 'silent': 0, 'scale_pos_weight': 1, 'nthread': 8, 'min_child_weight': 1, 'subsample': 0.9, 'eta': 0.1, 'objective': 'multi:softprob', 'max_depth': 3, 'gamma': 0.32}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 1 Mt
# 8 Nt
# 1.001 4.001
# 5 mt
# 80 nt
# (2748, 6) data_shape
# (2519, 12) X shape
# (2519, 1) y shape
# 69 no of classes
# top map results [{'map': 0.62256666666666671, 'max_depth': 3, 'min_child_weight': 1}, {'map': 0.62058000000000002, 'max_depth': 3, 'min_child_weight': 2}, {'map': 0.59038533333333332, 'max_depth': 2, 'min_child_weight': 1}]
# computed params for big grid 1, 8
# {'colsample_bytree': 0.7, 'silent': 0, 'scale_pos_weight': 1, 'nthread': 8, 'min_child_weight': 1, 'subsample': 0.9, 'eta': 0.1, 'objective': 'multi:softprob', 'max_depth': 3, 'gamma': 0.32}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 1 Mt
# 9 Nt
# 1.001 4.501
# 5 mt
# 90 nt
# (2839, 6) data_shape
# (2570, 12) X shape
# (2570, 1) y shape
# 66 no of classes
# top map results [{'map': 0.56892533333333339, 'max_depth': 3, 'min_child_weight': 2}, {'map': 0.56814633333333331, 'max_depth': 3, 'min_child_weight': 1}, {'map': 0.54672900000000002, 'max_depth': 2, 'min_child_weight': 1}]
# computed params for big grid 1, 9
# {'colsample_bytree': 0.7, 'silent': 0, 'scale_pos_weight': 1, 'nthread': 8, 'min_child_weight': 2, 'subsample': 0.9, 'eta': 0.1, 'objective': 'multi:softprob', 'max_depth': 3, 'gamma': 0.32}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 1 Mt
# 10 Nt
# 1.001 5.001
# 5 mt
# 100 nt
# (3781, 6) data_shape
# (3533, 12) X shape
# (3533, 1) y shape
# 85 no of classes
# top map results [{'map': 0.54205633333333336, 'max_depth': 3, 'min_child_weight': 1}, {'map': 0.53582566666666664, 'max_depth': 3, 'min_child_weight': 2}, {'map': 0.49844233333333327, 'max_depth': 2, 'min_child_weight': 1}]
# computed params for big grid 1, 10
# {'colsample_bytree': 0.7, 'silent': 0, 'scale_pos_weight': 1, 'nthread': 8, 'min_child_weight': 1, 'subsample': 0.9, 'eta': 0.1, 'objective': 'multi:softprob', 'max_depth': 3, 'gamma': 0.32}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 1 Mt
# 11 Nt
# 1.001 5.501
# 5 mt
# 110 nt
# (4442, 6) data_shape
# (4197, 12) X shape
# (4197, 1) y shape
# 73 no of classes
# top map results [{'map': 0.59542566666666674, 'max_depth': 3, 'min_child_weight': 1}, {'map': 0.59351933333333329, 'max_depth': 3, 'min_child_weight': 2}, {'map': 0.54229233333333338, 'max_depth': 2, 'min_child_weight': 1}]
# computed params for big grid 1, 11
# {'colsample_bytree': 0.7, 'silent': 0, 'scale_pos_weight': 1, 'nthread': 8, 'min_child_weight': 1, 'subsample': 0.9, 'eta': 0.1, 'objective': 'multi:softprob', 'max_depth': 3, 'gamma': 0.32}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 1 Mt
# 12 Nt
# 1.001 6.001
# 5 mt
# 120 nt
# (3486, 6) data_shape
# (3253, 12) X shape
# (3253, 1) y shape
# 64 no of classes
# top map results [{'map': 0.6100863333333334, 'max_depth': 3, 'min_child_weight': 1}, {'map': 0.60516600000000009, 'max_depth': 3, 'min_child_weight': 2}, {'map': 0.57164833333333331, 'max_depth': 2, 'min_child_weight': 2}]
# computed params for big grid 1, 12
# {'colsample_bytree': 0.7, 'silent': 0, 'scale_pos_weight': 1, 'nthread': 8, 'min_child_weight': 1, 'subsample': 0.9, 'eta': 0.1, 'objective': 'multi:softprob', 'max_depth': 3, 'gamma': 0.32}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 1 Mt
# 13 Nt
# 1.001 6.501
# 5 mt
# 130 nt
# (3118, 6) data_shape
# (2885, 12) X shape
# (2885, 1) y shape
# 78 no of classes
# top map results [{'map': 0.55809900000000001, 'max_depth': 3, 'min_child_weight': 1}, {'map': 0.55463066666666672, 'max_depth': 3, 'min_child_weight': 2}, {'map': 0.52480066666666669, 'max_depth': 2, 'min_child_weight': 1}]
# computed params for big grid 1, 13
# {'colsample_bytree': 0.7, 'silent': 0, 'scale_pos_weight': 1, 'nthread': 8, 'min_child_weight': 1, 'subsample': 0.9, 'eta': 0.1, 'objective': 'multi:softprob', 'max_depth': 3, 'gamma': 0.32}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 1 Mt
# 14 Nt
# 1.001 7.001
# 5 mt
# 140 nt
# (3757, 6) data_shape
# (3561, 12) X shape
# (3561, 1) y shape
# 68 no of classes
# top map results [{'map': 0.6672283333333332, 'max_depth': 3, 'min_child_weight': 1}, {'map': 0.66161199999999998, 'max_depth': 3, 'min_child_weight': 2}, {'map': 0.634934, 'max_depth': 2, 'min_child_weight': 1}]
# computed params for big grid 1, 14
# {'colsample_bytree': 0.7, 'silent': 0, 'scale_pos_weight': 1, 'nthread': 8, 'min_child_weight': 1, 'subsample': 0.9, 'eta': 0.1, 'objective': 'multi:softprob', 'max_depth': 3, 'gamma': 0.32}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 1 Mt
# 15 Nt
# 1.001 7.501
# 5 mt
# 150 nt
# (5597, 6) data_shape
# (5334, 12) X shape
# (5334, 1) y shape
# 73 no of classes
# top map results [{'map': 0.64360733333333331, 'max_depth': 3, 'min_child_weight': 1}, {'map': 0.64360700000000004, 'max_depth': 3, 'min_child_weight': 2}, {'map': 0.60423700000000002, 'max_depth': 2, 'min_child_weight': 1}]
# computed params for big grid 1, 15
# {'colsample_bytree': 0.7, 'silent': 0, 'scale_pos_weight': 1, 'nthread': 8, 'min_child_weight': 1, 'subsample': 0.9, 'eta': 0.1, 'objective': 'multi:softprob', 'max_depth': 3, 'gamma': 0.32}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 1 Mt
# 16 Nt
# 1.001 8.001
# 5 mt
# 160 nt
# (3330, 6) data_shape
# (3086, 12) X shape
# (3086, 1) y shape
# 62 no of classes
# top map results [{'map': 0.54798966666666671, 'max_depth': 3, 'min_child_weight': 1}, {'map': 0.54571999999999998, 'max_depth': 3, 'min_child_weight': 2}, {'map': 0.5119973333333333, 'max_depth': 2, 'min_child_weight': 1}]
# computed params for big grid 1, 16
# {'colsample_bytree': 0.7, 'silent': 0, 'scale_pos_weight': 1, 'nthread': 8, 'min_child_weight': 1, 'subsample': 0.9, 'eta': 0.1, 'objective': 'multi:softprob', 'max_depth': 3, 'gamma': 0.32}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 1 Mt
# 17 Nt
# 1.001 8.501
# 5 mt
# 170 nt
# (4148, 6) data_shape
# (3911, 12) X shape
# (3911, 1) y shape
# 61 no of classes
# top map results [{'map': 0.68713233333333334, 'max_depth': 3, 'min_child_weight': 1}, {'map': 0.68355066666666675, 'max_depth': 3, 'min_child_weight': 2}, {'map': 0.66282933333333338, 'max_depth': 2, 'min_child_weight': 1}]
# computed params for big grid 1, 17
# {'colsample_bytree': 0.7, 'silent': 0, 'scale_pos_weight': 1, 'nthread': 8, 'min_child_weight': 1, 'subsample': 0.9, 'eta': 0.1, 'objective': 'multi:softprob', 'max_depth': 3, 'gamma': 0.32}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 1 Mt
# 18 Nt
# 1.001 9.001
# 5 mt
# 180 nt
# (2292, 6) data_shape
# (2037, 12) X shape
# (2037, 1) y shape
# 62 no of classes
# top map results [{'map': 0.56161033333333332, 'max_depth': 3, 'min_child_weight': 1}, {'map': 0.55473766666666668, 'max_depth': 3, 'min_child_weight': 2}, {'map': 0.52675499999999997, 'max_depth': 2, 'min_child_weight': 1}]
# computed params for big grid 1, 18
# {'colsample_bytree': 0.7, 'silent': 0, 'scale_pos_weight': 1, 'nthread': 8, 'min_child_weight': 1, 'subsample': 0.9, 'eta': 0.1, 'objective': 'multi:softprob', 'max_depth': 3, 'gamma': 0.32}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 1 Mt
# 19 Nt
# 1.001 9.501
# 5 mt
# 190 nt
# (4024, 6) data_shape
# (3763, 12) X shape
# (3763, 1) y shape
# 81 no of classes
# top map results [{'map': 0.56406166666666657, 'max_depth': 3, 'min_child_weight': 1}, {'map': 0.55342899999999995, 'max_depth': 3, 'min_child_weight': 2}, {'map': 0.51807566666666671, 'max_depth': 2, 'min_child_weight': 1}]
# computed params for big grid 1, 19
# {'colsample_bytree': 0.7, 'silent': 0, 'scale_pos_weight': 1, 'nthread': 8, 'min_child_weight': 1, 'subsample': 0.9, 'eta': 0.1, 'objective': 'multi:softprob', 'max_depth': 3, 'gamma': 0.32}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 2 Mt
# 0 Nt
# 2.001 0.001
# 10 mt
# 0 nt
# (3651, 6) data_shape
# (3466, 12) X shape
# (3466, 1) y shape
# 51 no of classes
# top map results [{'map': 0.65079333333333333, 'max_depth': 3, 'min_child_weight': 1}, {'map': 0.64704200000000001, 'max_depth': 3, 'min_child_weight': 2}, {'map': 0.61241000000000001, 'max_depth': 2, 'min_child_weight': 1}]
# computed params for big grid 2, 0
# {'colsample_bytree': 0.7, 'silent': 0, 'scale_pos_weight': 1, 'nthread': 8, 'min_child_weight': 1, 'subsample': 0.9, 'eta': 0.1, 'objective': 'multi:softprob', 'max_depth': 3, 'gamma': 0.32}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 2 Mt
# 1 Nt
# 2.001 0.501
# 10 mt
# 10 nt
# (5439, 6) data_shape
# (5188, 12) X shape
# (5188, 1) y shape
# 65 no of classes
# top map results [{'map': 0.64411033333333334, 'max_depth': 3, 'min_child_weight': 1}, {'map': 0.64411000000000007, 'max_depth': 3, 'min_child_weight': 2}, {'map': 0.59475599999999995, 'max_depth': 2, 'min_child_weight': 2}]
# computed params for big grid 2, 1
# {'colsample_bytree': 0.7, 'silent': 0, 'scale_pos_weight': 1, 'nthread': 8, 'min_child_weight': 1, 'subsample': 0.9, 'eta': 0.1, 'objective': 'multi:softprob', 'max_depth': 3, 'gamma': 0.32}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 2 Mt
# 2 Nt
# 2.001 1.001
# 10 mt
# 20 nt
# (3553, 6) data_shape
# (3231, 12) X shape
# (3231, 1) y shape
# 82 no of classes
# top map results [{'map': 0.55184166666666667, 'max_depth': 3, 'min_child_weight': 1}, {'map': 0.54657966666666669, 'max_depth': 3, 'min_child_weight': 2}, {'map': 0.50324966666666671, 'max_depth': 2, 'min_child_weight': 1}]
# computed params for big grid 2, 2
# {'colsample_bytree': 0.7, 'silent': 0, 'scale_pos_weight': 1, 'nthread': 8, 'min_child_weight': 1, 'subsample': 0.9, 'eta': 0.1, 'objective': 'multi:softprob', 'max_depth': 3, 'gamma': 0.32}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 2 Mt
# 3 Nt
# 2.001 1.501
# 10 mt
# 30 nt
# (3071, 6) data_shape
# (2776, 12) X shape
# (2776, 1) y shape
# 81 no of classes
# top map results [{'map': 0.57837799999999995, 'max_depth': 3, 'min_child_weight': 1}, {'map': 0.56792766666666672, 'max_depth': 3, 'min_child_weight': 2}, {'map': 0.54630633333333334, 'max_depth': 2, 'min_child_weight': 1}]
# computed params for big grid 2, 3
# {'colsample_bytree': 0.7, 'silent': 0, 'scale_pos_weight': 1, 'nthread': 8, 'min_child_weight': 1, 'subsample': 0.9, 'eta': 0.1, 'objective': 'multi:softprob', 'max_depth': 3, 'gamma': 0.32}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 2 Mt
# 4 Nt
# 2.001 2.001
# 10 mt
# 40 nt
# (3717, 6) data_shape
# (3469, 12) X shape
# (3469, 1) y shape
# 76 no of classes
# top map results [{'map': 0.61966533333333329, 'max_depth': 3, 'min_child_weight': 1}, {'map': 0.61159166666666664, 'max_depth': 3, 'min_child_weight': 2}, {'map': 0.59025366666666679, 'max_depth': 2, 'min_child_weight': 2}]
# computed params for big grid 2, 4
# {'colsample_bytree': 0.7, 'silent': 0, 'scale_pos_weight': 1, 'nthread': 8, 'min_child_weight': 1, 'subsample': 0.9, 'eta': 0.1, 'objective': 'multi:softprob', 'max_depth': 3, 'gamma': 0.32}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 2 Mt
# 5 Nt
# 2.001 2.501
# 10 mt
# 50 nt
# (3556, 6) data_shape
# (3274, 12) X shape
# (3274, 1) y shape
# 78 no of classes
# top map results [{'map': 0.60311633333333337, 'max_depth': 3, 'min_child_weight': 2}, {'map': 0.60158900000000004, 'max_depth': 3, 'min_child_weight': 1}, {'map': 0.57867400000000002, 'max_depth': 2, 'min_child_weight': 1}]
# computed params for big grid 2, 5
# {'colsample_bytree': 0.7, 'silent': 0, 'scale_pos_weight': 1, 'nthread': 8, 'min_child_weight': 2, 'subsample': 0.9, 'eta': 0.1, 'objective': 'multi:softprob', 'max_depth': 3, 'gamma': 0.32}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 2 Mt
# 6 Nt
# 2.001 3.001
# 10 mt
# 60 nt
# (2010, 6) data_shape
# (1747, 12) X shape
# (1747, 1) y shape
# 72 no of classes
# top map results [{'map': 0.52577299999999993, 'max_depth': 3, 'min_child_weight': 1}, {'map': 0.50630033333333335, 'max_depth': 3, 'min_child_weight': 2}, {'map': 0.49427266666666664, 'max_depth': 2, 'min_child_weight': 1}]
# computed params for big grid 2, 6
# {'colsample_bytree': 0.7, 'silent': 0, 'scale_pos_weight': 1, 'nthread': 8, 'min_child_weight': 1, 'subsample': 0.9, 'eta': 0.1, 'objective': 'multi:softprob', 'max_depth': 3, 'gamma': 0.32}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 2 Mt
# 7 Nt
# 2.001 3.501
# 10 mt
# 70 nt
# (4361, 6) data_shape
# (4067, 12) X shape
# (4067, 1) y shape
# 73 no of classes
# top map results [{'map': 0.62509199999999998, 'max_depth': 3, 'min_child_weight': 1}, {'map': 0.61943399999999993, 'max_depth': 3, 'min_child_weight': 2}, {'map': 0.58696200000000009, 'max_depth': 2, 'min_child_weight': 1}]
# computed params for big grid 2, 7
# {'colsample_bytree': 0.7, 'silent': 0, 'scale_pos_weight': 1, 'nthread': 8, 'min_child_weight': 1, 'subsample': 0.9, 'eta': 0.1, 'objective': 'multi:softprob', 'max_depth': 3, 'gamma': 0.32}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 2 Mt
# 8 Nt
# 2.001 4.001
# 10 mt
# 80 nt
# (3975, 6) data_shape
# (3692, 12) X shape
# (3692, 1) y shape
# 64 no of classes
# top map results [{'map': 0.6387533333333334, 'max_depth': 3, 'min_child_weight': 1}, {'map': 0.63550133333333336, 'max_depth': 3, 'min_child_weight': 2}, {'map': 0.60894300000000001, 'max_depth': 2, 'min_child_weight': 1}]
# computed params for big grid 2, 8
# {'colsample_bytree': 0.7, 'silent': 0, 'scale_pos_weight': 1, 'nthread': 8, 'min_child_weight': 1, 'subsample': 0.9, 'eta': 0.1, 'objective': 'multi:softprob', 'max_depth': 3, 'gamma': 0.32}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 2 Mt
# 9 Nt
# 2.001 4.501
# 10 mt
# 90 nt
# (4141, 6) data_shape
# (3865, 12) X shape
# (3865, 1) y shape
# 94 no of classes
# top map results [{'map': 0.55305366666666667, 'max_depth': 3, 'min_child_weight': 1}, {'map': 0.55227700000000002, 'max_depth': 3, 'min_child_weight': 2}, {'map': 0.51190466666666667, 'max_depth': 2, 'min_child_weight': 2}]
# computed params for big grid 2, 9
# {'colsample_bytree': 0.7, 'silent': 0, 'scale_pos_weight': 1, 'nthread': 8, 'min_child_weight': 1, 'subsample': 0.9, 'eta': 0.1, 'objective': 'multi:softprob', 'max_depth': 3, 'gamma': 0.32}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 2 Mt
# 10 Nt
# 2.001 5.001
# 10 mt
# 100 nt
# (5644, 6) data_shape
# (5350, 12) X shape
# (5350, 1) y shape
# 85 no of classes
# top map results [{'map': 0.62628533333333325, 'max_depth': 3, 'min_child_weight': 1}, {'map': 0.620116, 'max_depth': 3, 'min_child_weight': 2}, {'map': 0.59132533333333326, 'max_depth': 2, 'min_child_weight': 2}]
# computed params for big grid 2, 10
# {'colsample_bytree': 0.7, 'silent': 0, 'scale_pos_weight': 1, 'nthread': 8, 'min_child_weight': 1, 'subsample': 0.9, 'eta': 0.1, 'objective': 'multi:softprob', 'max_depth': 3, 'gamma': 0.32}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 2 Mt
# 11 Nt
# 2.001 5.501
# 10 mt
# 110 nt
# (3253, 6) data_shape
# (2943, 12) X shape
# (2943, 1) y shape
# 75 no of classes
# top map results [{'map': 0.57050633333333334, 'max_depth': 3, 'min_child_weight': 1}, {'map': 0.56405033333333343, 'max_depth': 3, 'min_child_weight': 2}, {'map': 0.541964, 'max_depth': 2, 'min_child_weight': 1}]
# computed params for big grid 2, 11
# {'colsample_bytree': 0.7, 'silent': 0, 'scale_pos_weight': 1, 'nthread': 8, 'min_child_weight': 1, 'subsample': 0.9, 'eta': 0.1, 'objective': 'multi:softprob', 'max_depth': 3, 'gamma': 0.32}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 2 Mt
# 12 Nt
# 2.001 6.001
# 10 mt
# 120 nt
# (4882, 6) data_shape
# (4667, 12) X shape
# (4667, 1) y shape
# 76 no of classes
# top map results [{'map': 0.59656999999999993, 'max_depth': 3, 'min_child_weight': 1}, {'map': 0.592283, 'max_depth': 3, 'min_child_weight': 2}, {'map': 0.5599143333333334, 'max_depth': 2, 'min_child_weight': 1}]
# computed params for big grid 2, 12
# {'colsample_bytree': 0.7, 'silent': 0, 'scale_pos_weight': 1, 'nthread': 8, 'min_child_weight': 1, 'subsample': 0.9, 'eta': 0.1, 'objective': 'multi:softprob', 'max_depth': 3, 'gamma': 0.32}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 2 Mt
# 13 Nt
# 2.001 6.501
# 10 mt
# 130 nt
# (5145, 6) data_shape
# (4904, 12) X shape
# (4904, 1) y shape
# 85 no of classes
# top map results [{'map': 0.63688300000000009, 'max_depth': 3, 'min_child_weight': 1}, {'map': 0.63463899999999995, 'max_depth': 3, 'min_child_weight': 2}, {'map': 0.60669099999999998, 'max_depth': 2, 'min_child_weight': 1}]
# computed params for big grid 2, 13
# {'colsample_bytree': 0.7, 'silent': 0, 'scale_pos_weight': 1, 'nthread': 8, 'min_child_weight': 1, 'subsample': 0.9, 'eta': 0.1, 'objective': 'multi:softprob', 'max_depth': 3, 'gamma': 0.32}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 2 Mt
# 14 Nt
# 2.001 7.001
# 10 mt
# 140 nt
# (4136, 6) data_shape
# (3860, 12) X shape
# (3860, 1) y shape
# 64 no of classes
# top map results [{'map': 0.62804533333333334, 'max_depth': 3, 'min_child_weight': 1}, {'map': 0.62363933333333332, 'max_depth': 3, 'min_child_weight': 2}, {'map': 0.57879733333333327, 'max_depth': 2, 'min_child_weight': 2}]
# computed params for big grid 2, 14
# {'colsample_bytree': 0.7, 'silent': 0, 'scale_pos_weight': 1, 'nthread': 8, 'min_child_weight': 1, 'subsample': 0.9, 'eta': 0.1, 'objective': 'multi:softprob', 'max_depth': 3, 'gamma': 0.32}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 2 Mt
# 15 Nt
# 2.001 7.501
# 10 mt
# 150 nt
# (4541, 6) data_shape
# (4275, 12) X shape
# (4275, 1) y shape
# 81 no of classes
# top map results [{'map': 0.57824566666666666, 'max_depth': 3, 'min_child_weight': 2}, {'map': 0.57707600000000003, 'max_depth': 3, 'min_child_weight': 1}, {'map': 0.54152033333333327, 'max_depth': 2, 'min_child_weight': 2}]
# computed params for big grid 2, 15
# {'colsample_bytree': 0.7, 'silent': 0, 'scale_pos_weight': 1, 'nthread': 8, 'min_child_weight': 2, 'subsample': 0.9, 'eta': 0.1, 'objective': 'multi:softprob', 'max_depth': 3, 'gamma': 0.32}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 2 Mt
# 16 Nt
# 2.001 8.001
# 10 mt
# 160 nt
# (4280, 6) data_shape
# (4009, 12) X shape
# (4009, 1) y shape
# 61 no of classes
# top map results [{'map': 0.65469066666666664, 'max_depth': 3, 'min_child_weight': 2}, {'map': 0.65369299999999997, 'max_depth': 3, 'min_child_weight': 1}, {'map': 0.623004, 'max_depth': 2, 'min_child_weight': 2}]
# computed params for big grid 2, 16
# {'colsample_bytree': 0.7, 'silent': 0, 'scale_pos_weight': 1, 'nthread': 8, 'min_child_weight': 2, 'subsample': 0.9, 'eta': 0.1, 'objective': 'multi:softprob', 'max_depth': 3, 'gamma': 0.32}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 2 Mt
# 17 Nt
# 2.001 8.501
# 10 mt
# 170 nt
# (2525, 6) data_shape
# (2254, 12) X shape
# (2254, 1) y shape
# 59 no of classes
# top map results [{'map': 0.61606733333333341, 'max_depth': 3, 'min_child_weight': 1}, {'map': 0.60541500000000004, 'max_depth': 3, 'min_child_weight': 2}, {'map': 0.58455433333333329, 'max_depth': 2, 'min_child_weight': 1}]
# computed params for big grid 2, 17
# {'colsample_bytree': 0.7, 'silent': 0, 'scale_pos_weight': 1, 'nthread': 8, 'min_child_weight': 1, 'subsample': 0.9, 'eta': 0.1, 'objective': 'multi:softprob', 'max_depth': 3, 'gamma': 0.32}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 2 Mt
# 18 Nt
# 2.001 9.001
# 10 mt
# 180 nt
# (5668, 6) data_shape
# (5382, 12) X shape
# (5382, 1) y shape
# 71 no of classes
# top map results [{'map': 0.67001100000000002, 'max_depth': 3, 'min_child_weight': 1}, {'map': 0.66796733333333336, 'max_depth': 3, 'min_child_weight': 2}, {'map': 0.64567033333333335, 'max_depth': 2, 'min_child_weight': 2}]
# computed params for big grid 2, 18
# {'colsample_bytree': 0.7, 'silent': 0, 'scale_pos_weight': 1, 'nthread': 8, 'min_child_weight': 1, 'subsample': 0.9, 'eta': 0.1, 'objective': 'multi:softprob', 'max_depth': 3, 'gamma': 0.32}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 2 Mt
# 19 Nt
# 2.001 9.501
# 10 mt
# 190 nt
# (4448, 6) data_shape
# (4170, 12) X shape
# (4170, 1) y shape
# 83 no of classes
# top map results [{'map': 0.61294966666666661, 'max_depth': 3, 'min_child_weight': 1}, {'map': 0.60215800000000008, 'max_depth': 3, 'min_child_weight': 2}, {'map': 0.57362100000000005, 'max_depth': 2, 'min_child_weight': 1}]
# computed params for big grid 2, 19
# {'colsample_bytree': 0.7, 'silent': 0, 'scale_pos_weight': 1, 'nthread': 8, 'min_child_weight': 1, 'subsample': 0.9, 'eta': 0.1, 'objective': 'multi:softprob', 'max_depth': 3, 'gamma': 0.32}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 3 Mt
# 0 Nt
# 3.001 0.001
# 15 mt
# 0 nt
# (4388, 6) data_shape
# (4194, 12) X shape
# (4194, 1) y shape
# 59 no of classes
# top map results [{'map': 0.62041000000000002, 'max_depth': 3, 'min_child_weight': 1}, {'map': 0.61897966666666659, 'max_depth': 3, 'min_child_weight': 2}, {'map': 0.58750599999999997, 'max_depth': 2, 'min_child_weight': 1}]
# computed params for big grid 3, 0
# {'colsample_bytree': 0.7, 'silent': 0, 'scale_pos_weight': 1, 'nthread': 8, 'min_child_weight': 1, 'subsample': 0.9, 'eta': 0.1, 'objective': 'multi:softprob', 'max_depth': 3, 'gamma': 0.32}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 3 Mt
# 1 Nt
# 3.001 0.501
# 15 mt
# 10 nt
# (2559, 6) data_shape
# (2290, 12) X shape
# (2290, 1) y shape
# 60 no of classes
# top map results [{'map': 0.68545200000000006, 'max_depth': 3, 'min_child_weight': 1}, {'map': 0.68326799999999999, 'max_depth': 3, 'min_child_weight': 2}, {'map': 0.64788100000000004, 'max_depth': 2, 'min_child_weight': 1}]
# computed params for big grid 3, 1
# {'colsample_bytree': 0.7, 'silent': 0, 'scale_pos_weight': 1, 'nthread': 8, 'min_child_weight': 1, 'subsample': 0.9, 'eta': 0.1, 'objective': 'multi:softprob', 'max_depth': 3, 'gamma': 0.32}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 3 Mt
# 2 Nt
# 3.001 1.001
# 15 mt
# 20 nt
# (3462, 6) data_shape
# (3143, 12) X shape
# (3143, 1) y shape
# 93 no of classes
# top map results [{'map': 0.52976766666666675, 'max_depth': 3, 'min_child_weight': 1}, {'map': 0.52913100000000002, 'max_depth': 3, 'min_child_weight': 2}, {'map': 0.50270599999999999, 'max_depth': 2, 'min_child_weight': 1}]
# computed params for big grid 3, 2
# {'colsample_bytree': 0.7, 'silent': 0, 'scale_pos_weight': 1, 'nthread': 8, 'min_child_weight': 1, 'subsample': 0.9, 'eta': 0.1, 'objective': 'multi:softprob', 'max_depth': 3, 'gamma': 0.32}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 3 Mt
# 3 Nt
# 3.001 1.501
# 15 mt
# 30 nt
# (4830, 6) data_shape
# (4525, 12) X shape
# (4525, 1) y shape
# 72 no of classes
# top map results [{'map': 0.64854099999999992, 'max_depth': 3, 'min_child_weight': 1}, {'map': 0.64655200000000002, 'max_depth': 3, 'min_child_weight': 2}, {'map': 0.62820500000000001, 'max_depth': 2, 'min_child_weight': 1}]
# computed params for big grid 3, 3
# {'colsample_bytree': 0.7, 'silent': 0, 'scale_pos_weight': 1, 'nthread': 8, 'min_child_weight': 1, 'subsample': 0.9, 'eta': 0.1, 'objective': 'multi:softprob', 'max_depth': 3, 'gamma': 0.32}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 3 Mt
# 4 Nt
# 3.001 2.001
# 15 mt
# 40 nt
# (4718, 6) data_shape
# (4411, 12) X shape
# (4411, 1) y shape
# 74 no of classes
# top map results [{'map': 0.69863966666666666, 'max_depth': 3, 'min_child_weight': 1}, {'map': 0.69659866666666659, 'max_depth': 3, 'min_child_weight': 2}, {'map': 0.66281166666666669, 'max_depth': 2, 'min_child_weight': 1}]
# computed params for big grid 3, 4
# {'colsample_bytree': 0.7, 'silent': 0, 'scale_pos_weight': 1, 'nthread': 8, 'min_child_weight': 1, 'subsample': 0.9, 'eta': 0.1, 'objective': 'multi:softprob', 'max_depth': 3, 'gamma': 0.32}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 3 Mt
# 5 Nt
# 3.001 2.501
# 15 mt
# 50 nt
# (4029, 6) data_shape
# (3789, 12) X shape
# (3789, 1) y shape
# 77 no of classes
# top map results [{'map': 0.62549500000000002, 'max_depth': 3, 'min_child_weight': 1}, {'map': 0.6252306666666666, 'max_depth': 3, 'min_child_weight': 2}, {'map': 0.59276833333333334, 'max_depth': 2, 'min_child_weight': 2}]
# computed params for big grid 3, 5
# {'colsample_bytree': 0.7, 'silent': 0, 'scale_pos_weight': 1, 'nthread': 8, 'min_child_weight': 1, 'subsample': 0.9, 'eta': 0.1, 'objective': 'multi:softprob', 'max_depth': 3, 'gamma': 0.32}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 3 Mt
# 6 Nt
# 3.001 3.001
# 15 mt
# 60 nt
# (3908, 6) data_shape
# (3606, 12) X shape
# (3606, 1) y shape
# 86 no of classes
# top map results [{'map': 0.60205199999999992, 'max_depth': 3, 'min_child_weight': 1}, {'map': 0.59484199999999998, 'max_depth': 3, 'min_child_weight': 2}, {'map': 0.55684933333333342, 'max_depth': 2, 'min_child_weight': 1}]
# computed params for big grid 3, 6
# {'colsample_bytree': 0.7, 'silent': 0, 'scale_pos_weight': 1, 'nthread': 8, 'min_child_weight': 1, 'subsample': 0.9, 'eta': 0.1, 'objective': 'multi:softprob', 'max_depth': 3, 'gamma': 0.32}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 3 Mt
# 7 Nt
# 3.001 3.501
# 15 mt
# 70 nt
# (3434, 6) data_shape
# (3186, 12) X shape
# (3186, 1) y shape
# 84 no of classes
# top map results [{'map': 0.58976766666666658, 'max_depth': 3, 'min_child_weight': 1}, {'map': 0.5831763333333333, 'max_depth': 3, 'min_child_weight': 2}, {'map': 0.55398633333333336, 'max_depth': 2, 'min_child_weight': 1}]
# computed params for big grid 3, 7
# {'colsample_bytree': 0.7, 'silent': 0, 'scale_pos_weight': 1, 'nthread': 8, 'min_child_weight': 1, 'subsample': 0.9, 'eta': 0.1, 'objective': 'multi:softprob', 'max_depth': 3, 'gamma': 0.32}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 3 Mt
# 8 Nt
# 3.001 4.001
# 15 mt
# 80 nt
# (3774, 6) data_shape
# (3476, 12) X shape
# (3476, 1) y shape
# 76 no of classes
# top map results [{'map': 0.6301093333333333, 'max_depth': 3, 'min_child_weight': 1}, {'map': 0.62550333333333341, 'max_depth': 3, 'min_child_weight': 2}, {'map': 0.58059899999999998, 'max_depth': 2, 'min_child_weight': 1}]
# computed params for big grid 3, 8
# {'colsample_bytree': 0.7, 'silent': 0, 'scale_pos_weight': 1, 'nthread': 8, 'min_child_weight': 1, 'subsample': 0.9, 'eta': 0.1, 'objective': 'multi:softprob', 'max_depth': 3, 'gamma': 0.32}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 3 Mt
# 9 Nt
# 3.001 4.501
# 15 mt
# 90 nt
# (3842, 6) data_shape
# (3556, 12) X shape
# (3556, 1) y shape
# 82 no of classes
# top map results [{'map': 0.57862166666666659, 'max_depth': 3, 'min_child_weight': 1}, {'map': 0.57637133333333335, 'max_depth': 3, 'min_child_weight': 2}, {'map': 0.5437413333333333, 'max_depth': 2, 'min_child_weight': 1}]
# computed params for big grid 3, 9
# {'colsample_bytree': 0.7, 'silent': 0, 'scale_pos_weight': 1, 'nthread': 8, 'min_child_weight': 1, 'subsample': 0.9, 'eta': 0.1, 'objective': 'multi:softprob', 'max_depth': 3, 'gamma': 0.32}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 3 Mt
# 10 Nt
# 3.001 5.001
# 15 mt
# 100 nt
# (4081, 6) data_shape
# (3797, 12) X shape
# (3797, 1) y shape
# 74 no of classes
# top map results [{'map': 0.61712766666666674, 'max_depth': 3, 'min_child_weight': 1}, {'map': 0.61475633333333335, 'max_depth': 3, 'min_child_weight': 2}, {'map': 0.58050066666666666, 'max_depth': 2, 'min_child_weight': 1}]
# computed params for big grid 3, 10
# {'colsample_bytree': 0.7, 'silent': 0, 'scale_pos_weight': 1, 'nthread': 8, 'min_child_weight': 1, 'subsample': 0.9, 'eta': 0.1, 'objective': 'multi:softprob', 'max_depth': 3, 'gamma': 0.32}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 3 Mt
# 11 Nt
# 3.001 5.501
# 15 mt
# 110 nt
# (5793, 6) data_shape
# (5513, 12) X shape
# (5513, 1) y shape
# 78 no of classes
# top map results [{'map': 0.63799666666666666, 'max_depth': 3, 'min_child_weight': 1}, {'map': 0.6374523333333334, 'max_depth': 3, 'min_child_weight': 2}, {'map': 0.60460866666666668, 'max_depth': 2, 'min_child_weight': 1}]
# computed params for big grid 3, 11
# {'colsample_bytree': 0.7, 'silent': 0, 'scale_pos_weight': 1, 'nthread': 8, 'min_child_weight': 1, 'subsample': 0.9, 'eta': 0.1, 'objective': 'multi:softprob', 'max_depth': 3, 'gamma': 0.32}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 3 Mt
# 12 Nt
# 3.001 6.001
# 15 mt
# 120 nt
# (4107, 6) data_shape
# (3832, 12) X shape
# (3832, 1) y shape
# 69 no of classes
# ...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 8 Mt
# 16 Nt
# 8.001 8.001
# 40 mt
# 160 nt
# (3485, 6) data_shape
# (3228, 12) X shape
# (3228, 1) y shape
# 75 no of classes
# top map results [{'map': 0.57713766666666666, 'max_depth': 3, 'min_child_weight': 1}, {'map': 0.56846333333333332, 'max_depth': 3, 'min_child_weight': 2}, {'map': 0.54646833333333333, 'max_depth': 2, 'min_child_weight': 1}]
# computed params for big grid 8, 16
# {'colsample_bytree': 0.7, 'silent': 0, 'scale_pos_weight': 1, 'nthread': 8, 'min_child_weight': 1, 'subsample': 0.9, 'eta': 0.1, 'objective': 'multi:softprob', 'max_depth': 3, 'gamma': 0.32}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 8 Mt
# 17 Nt
# 8.001 8.501
# 40 mt
# 170 nt
# (3270, 6) data_shape
# (2987, 12) X shape
# (2987, 1) y shape
# 68 no of classes
# top map results [{'map': 0.55879433333333328, 'max_depth': 3, 'min_child_weight': 1}, {'map': 0.55510899999999996, 'max_depth': 3, 'min_child_weight': 2}, {'map': 0.52797333333333341, 'max_depth': 2, 'min_child_weight': 1}]
# computed params for big grid 8, 17
# {'colsample_bytree': 0.7, 'silent': 0, 'scale_pos_weight': 1, 'nthread': 8, 'min_child_weight': 1, 'subsample': 0.9, 'eta': 0.1, 'objective': 'multi:softprob', 'max_depth': 3, 'gamma': 0.32}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 8 Mt
# 18 Nt
# 8.001 9.001
# 40 mt
# 180 nt
# (3750, 6) data_shape
# (3502, 12) X shape
# (3502, 1) y shape
# 89 no of classes
# top map results [{'map': 0.56812333333333331, 'max_depth': 3, 'min_child_weight': 1}, {'map': 0.561554, 'max_depth': 3, 'min_child_weight': 2}, {'map': 0.53213366666666662, 'max_depth': 2, 'min_child_weight': 1}]
# computed params for big grid 8, 18
# {'colsample_bytree': 0.7, 'silent': 0, 'scale_pos_weight': 1, 'nthread': 8, 'min_child_weight': 1, 'subsample': 0.9, 'eta': 0.1, 'objective': 'multi:softprob', 'max_depth': 3, 'gamma': 0.32}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 8 Mt
# 19 Nt
# 8.001 9.501
# 40 mt
# 190 nt
# (2783, 6) data_shape
# (2548, 12) X shape
# (2548, 1) y shape
# 65 no of classes
# top map results [{'map': 0.62465633333333337, 'max_depth': 3, 'min_child_weight': 1}, {'map': 0.6226936666666667, 'max_depth': 3, 'min_child_weight': 2}, {'map': 0.59206900000000007, 'max_depth': 2, 'min_child_weight': 1}]
# computed params for big grid 8, 19
# {'colsample_bytree': 0.7, 'silent': 0, 'scale_pos_weight': 1, 'nthread': 8, 'min_child_weight': 1, 'subsample': 0.9, 'eta': 0.1, 'objective': 'multi:softprob', 'max_depth': 3, 'gamma': 0.32}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 9 Mt
# 0 Nt
# 9.001 0.001
# 45 mt
# 0 nt
# (4629, 6) data_shape
# (4458, 12) X shape
# (4458, 1) y shape
# 64 no of classes
# top map results [{'map': 0.66061000000000003, 'max_depth': 3, 'min_child_weight': 1}, {'map': 0.65589933333333328, 'max_depth': 3, 'min_child_weight': 2}, {'map': 0.61350399999999994, 'max_depth': 2, 'min_child_weight': 1}]
# computed params for big grid 9, 0
# {'colsample_bytree': 0.7, 'silent': 0, 'scale_pos_weight': 1, 'nthread': 8, 'min_child_weight': 1, 'subsample': 0.9, 'eta': 0.1, 'objective': 'multi:softprob', 'max_depth': 3, 'gamma': 0.32}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 9 Mt
# 1 Nt
# 9.001 0.501
# 45 mt
# 10 nt
# (1993, 6) data_shape
# (1755, 12) X shape
# (1755, 1) y shape
# 62 no of classes
# top map results [{'map': 0.55783499999999997, 'max_depth': 3, 'min_child_weight': 1}, {'map': 0.54757866666666666, 'max_depth': 3, 'min_child_weight': 2}, {'map': 0.51908833333333326, 'max_depth': 2, 'min_child_weight': 1}]
# computed params for big grid 9, 1
# {'colsample_bytree': 0.7, 'silent': 0, 'scale_pos_weight': 1, 'nthread': 8, 'min_child_weight': 1, 'subsample': 0.9, 'eta': 0.1, 'objective': 'multi:softprob', 'max_depth': 3, 'gamma': 0.32}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 9 Mt
# 2 Nt
# 9.001 1.001
# 45 mt
# 20 nt
# (5086, 6) data_shape
# (4828, 12) X shape
# (4828, 1) y shape
# 76 no of classes
# top map results [{'map': 0.6737103333333333, 'max_depth': 3, 'min_child_weight': 1}, {'map': 0.66915266666666673, 'max_depth': 3, 'min_child_weight': 2}, {'map': 0.63496999999999992, 'max_depth': 2, 'min_child_weight': 1}]
# computed params for big grid 9, 2
# {'colsample_bytree': 0.7, 'silent': 0, 'scale_pos_weight': 1, 'nthread': 8, 'min_child_weight': 1, 'subsample': 0.9, 'eta': 0.1, 'objective': 'multi:softprob', 'max_depth': 3, 'gamma': 0.32}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 9 Mt
# 3 Nt
# 9.001 1.501
# 45 mt
# 30 nt
# (5776, 6) data_shape
# (5522, 12) X shape
# (5522, 1) y shape
# 70 no of classes
# top map results [{'map': 0.66394933333333339, 'max_depth': 3, 'min_child_weight': 1}, {'map': 0.66195633333333337, 'max_depth': 3, 'min_child_weight': 2}, {'map': 0.62155800000000005, 'max_depth': 2, 'min_child_weight': 1}]
# computed params for big grid 9, 3
# {'colsample_bytree': 0.7, 'silent': 0, 'scale_pos_weight': 1, 'nthread': 8, 'min_child_weight': 1, 'subsample': 0.9, 'eta': 0.1, 'objective': 'multi:softprob', 'max_depth': 3, 'gamma': 0.32}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 9 Mt
# 4 Nt
# 9.001 2.001
# 45 mt
# 40 nt
# (2786, 6) data_shape
# (2563, 12) X shape
# (2563, 1) y shape
# 57 no of classes
# top map results [{'map': 0.68501166666666669, 'max_depth': 3, 'min_child_weight': 1}, {'map': 0.6775956666666666, 'max_depth': 3, 'min_child_weight': 2}, {'map': 0.6514443333333334, 'max_depth': 2, 'min_child_weight': 1}]
# computed params for big grid 9, 4
# {'colsample_bytree': 0.7, 'silent': 0, 'scale_pos_weight': 1, 'nthread': 8, 'min_child_weight': 1, 'subsample': 0.9, 'eta': 0.1, 'objective': 'multi:softprob', 'max_depth': 3, 'gamma': 0.32}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 9 Mt
# 5 Nt
# 9.001 2.501
# 45 mt
# 50 nt
# (3834, 6) data_shape
# (3570, 12) X shape
# (3570, 1) y shape
# 77 no of classes
# top map results [{'map': 0.58599466666666666, 'max_depth': 3, 'min_child_weight': 1}, {'map': 0.58011233333333334, 'max_depth': 3, 'min_child_weight': 2}, {'map': 0.53837499999999994, 'max_depth': 2, 'min_child_weight': 2}]
# computed params for big grid 9, 5
# {'colsample_bytree': 0.7, 'silent': 0, 'scale_pos_weight': 1, 'nthread': 8, 'min_child_weight': 1, 'subsample': 0.9, 'eta': 0.1, 'objective': 'multi:softprob', 'max_depth': 3, 'gamma': 0.32}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 9 Mt
# 6 Nt
# 9.001 3.001
# 45 mt
# 60 nt
# (3980, 6) data_shape
# (3756, 12) X shape
# (3756, 1) y shape
# 81 no of classes
# top map results [{'map': 0.60729500000000003, 'max_depth': 3, 'min_child_weight': 1}, {'map': 0.60117133333333328, 'max_depth': 3, 'min_child_weight': 2}, {'map': 0.56655999999999995, 'max_depth': 2, 'min_child_weight': 1}]
# computed params for big grid 9, 6
# {'colsample_bytree': 0.7, 'silent': 0, 'scale_pos_weight': 1, 'nthread': 8, 'min_child_weight': 1, 'subsample': 0.9, 'eta': 0.1, 'objective': 'multi:softprob', 'max_depth': 3, 'gamma': 0.32}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 9 Mt
# 7 Nt
# 9.001 3.501
# 45 mt
# 70 nt
# (3219, 6) data_shape
# (3001, 12) X shape
# (3001, 1) y shape
# 67 no of classes
# top map results [{'map': 0.6263333333333333, 'max_depth': 3, 'min_child_weight': 1}, {'map': 0.626, 'max_depth': 3, 'min_child_weight': 2}, {'map': 0.59233333333333327, 'max_depth': 2, 'min_child_weight': 1}]
# computed params for big grid 9, 7
# {'colsample_bytree': 0.7, 'silent': 0, 'scale_pos_weight': 1, 'nthread': 8, 'min_child_weight': 1, 'subsample': 0.9, 'eta': 0.1, 'objective': 'multi:softprob', 'max_depth': 3, 'gamma': 0.32}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 9 Mt
# 8 Nt
# 9.001 4.001
# 45 mt
# 80 nt
# (4606, 6) data_shape
# (4317, 12) X shape
# (4317, 1) y shape
# 74 no of classes
# top map results [{'map': 0.6448923333333334, 'max_depth': 3, 'min_child_weight': 1}, {'map': 0.64280766666666667, 'max_depth': 3, 'min_child_weight': 2}, {'map': 0.6031966666666666, 'max_depth': 2, 'min_child_weight': 1}]
# computed params for big grid 9, 8
# {'colsample_bytree': 0.7, 'silent': 0, 'scale_pos_weight': 1, 'nthread': 8, 'min_child_weight': 1, 'subsample': 0.9, 'eta': 0.1, 'objective': 'multi:softprob', 'max_depth': 3, 'gamma': 0.32}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 9 Mt
# 9 Nt
# 9.001 4.501
# 45 mt
# 90 nt
# (5417, 6) data_shape
# (5158, 12) X shape
# (5158, 1) y shape
# 89 no of classes
# top map results [{'map': 0.61547433333333335, 'max_depth': 3, 'min_child_weight': 1}, {'map': 0.6108203333333333, 'max_depth': 3, 'min_child_weight': 2}, {'map': 0.57688566666666663, 'max_depth': 2, 'min_child_weight': 1}]
# computed params for big grid 9, 9
# {'colsample_bytree': 0.7, 'silent': 0, 'scale_pos_weight': 1, 'nthread': 8, 'min_child_weight': 1, 'subsample': 0.9, 'eta': 0.1, 'objective': 'multi:softprob', 'max_depth': 3, 'gamma': 0.32}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 9 Mt
# 10 Nt
# 9.001 5.001
# 45 mt
# 100 nt
# (3256, 6) data_shape
# (3039, 12) X shape
# (3039, 1) y shape
# 73 no of classes
# top map results [{'map': 0.59822333333333333, 'max_depth': 3, 'min_child_weight': 1}, {'map': 0.59229999999999994, 'max_depth': 3, 'min_child_weight': 2}, {'map': 0.56498833333333331, 'max_depth': 2, 'min_child_weight': 2}]
# computed params for big grid 9, 10
# {'colsample_bytree': 0.7, 'silent': 0, 'scale_pos_weight': 1, 'nthread': 8, 'min_child_weight': 1, 'subsample': 0.9, 'eta': 0.1, 'objective': 'multi:softprob', 'max_depth': 3, 'gamma': 0.32}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 9 Mt
# 11 Nt
# 9.001 5.501
# 45 mt
# 110 nt
# (3540, 6) data_shape
# (3297, 12) X shape
# (3297, 1) y shape
# 62 no of classes
# top map results [{'map': 0.65362466666666663, 'max_depth': 3, 'min_child_weight': 1}, {'map': 0.65210800000000002, 'max_depth': 3, 'min_child_weight': 2}, {'map': 0.61540799999999996, 'max_depth': 2, 'min_child_weight': 2}]
# computed params for big grid 9, 11
# {'colsample_bytree': 0.7, 'silent': 0, 'scale_pos_weight': 1, 'nthread': 8, 'min_child_weight': 1, 'subsample': 0.9, 'eta': 0.1, 'objective': 'multi:softprob', 'max_depth': 3, 'gamma': 0.32}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 9 Mt
# 12 Nt
# 9.001 6.001
# 45 mt
# 120 nt
# (2866, 6) data_shape
# (2633, 12) X shape
# (2633, 1) y shape
# 64 no of classes
# top map results [{'map': 0.56974533333333344, 'max_depth': 3, 'min_child_weight': 1}, {'map': 0.56024333333333332, 'max_depth': 3, 'min_child_weight': 2}, {'map': 0.52451533333333333, 'max_depth': 2, 'min_child_weight': 1}]
# computed params for big grid 9, 12
# {'colsample_bytree': 0.7, 'silent': 0, 'scale_pos_weight': 1, 'nthread': 8, 'min_child_weight': 1, 'subsample': 0.9, 'eta': 0.1, 'objective': 'multi:softprob', 'max_depth': 3, 'gamma': 0.32}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 9 Mt
# 13 Nt
# 9.001 6.501
# 45 mt
# 130 nt
# (4244, 6) data_shape
# (3996, 12) X shape
# (3996, 1) y shape
# 77 no of classes
# top map results [{'map': 0.6333833333333333, 'max_depth': 3, 'min_child_weight': 1}, {'map': 0.62988, 'max_depth': 3, 'min_child_weight': 2}, {'map': 0.59959933333333337, 'max_depth': 2, 'min_child_weight': 1}]
# computed params for big grid 9, 13
# {'colsample_bytree': 0.7, 'silent': 0, 'scale_pos_weight': 1, 'nthread': 8, 'min_child_weight': 1, 'subsample': 0.9, 'eta': 0.1, 'objective': 'multi:softprob', 'max_depth': 3, 'gamma': 0.32}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 9 Mt
# 14 Nt
# 9.001 7.001
# 45 mt
# 140 nt
# (3715, 6) data_shape
# (3470, 12) X shape
# (3470, 1) y shape
# 78 no of classes
# top map results [{'map': 0.62370233333333325, 'max_depth': 3, 'min_child_weight': 1}, {'map': 0.61303333333333332, 'max_depth': 3, 'min_child_weight': 2}, {'map': 0.58362199999999997, 'max_depth': 2, 'min_child_weight': 1}]
# computed params for big grid 9, 14
# {'colsample_bytree': 0.7, 'silent': 0, 'scale_pos_weight': 1, 'nthread': 8, 'min_child_weight': 1, 'subsample': 0.9, 'eta': 0.1, 'objective': 'multi:softprob', 'max_depth': 3, 'gamma': 0.32}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 9 Mt
# 15 Nt
# 9.001 7.501
# 45 mt
# 150 nt
# (3708, 6) data_shape
# (3474, 12) X shape
# (3474, 1) y shape
# 59 no of classes
# top map results [{'map': 0.66177333333333344, 'max_depth': 3, 'min_child_weight': 1}, {'map': 0.66119766666666668, 'max_depth': 3, 'min_child_weight': 2}, {'map': 0.62838199999999989, 'max_depth': 2, 'min_child_weight': 1}]
# computed params for big grid 9, 15
# {'colsample_bytree': 0.7, 'silent': 0, 'scale_pos_weight': 1, 'nthread': 8, 'min_child_weight': 1, 'subsample': 0.9, 'eta': 0.1, 'objective': 'multi:softprob', 'max_depth': 3, 'gamma': 0.32}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 9 Mt
# 16 Nt
# 9.001 8.001
# 45 mt
# 160 nt
# (4039, 6) data_shape
# (3830, 12) X shape
# (3830, 1) y shape
# 78 no of classes
# top map results [{'map': 0.6091953333333332, 'max_depth': 3, 'min_child_weight': 1}, {'map': 0.60501566666666662, 'max_depth': 3, 'min_child_weight': 2}, {'map': 0.56922700000000004, 'max_depth': 2, 'min_child_weight': 1}]
# computed params for big grid 9, 16
# {'colsample_bytree': 0.7, 'silent': 0, 'scale_pos_weight': 1, 'nthread': 8, 'min_child_weight': 1, 'subsample': 0.9, 'eta': 0.1, 'objective': 'multi:softprob', 'max_depth': 3, 'gamma': 0.32}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 9 Mt
# 17 Nt
# 9.001 8.501
# 45 mt
# 170 nt
# (6336, 6) data_shape
# (6099, 12) X shape
# (6099, 1) y shape
# 65 no of classes
# top map results [{'map': 0.63649766666666674, 'max_depth': 3, 'min_child_weight': 1}, {'map': 0.63502233333333324, 'max_depth': 3, 'min_child_weight': 2}, {'map': 0.60813233333333339, 'max_depth': 2, 'min_child_weight': 1}]
# computed params for big grid 9, 17
# {'colsample_bytree': 0.7, 'silent': 0, 'scale_pos_weight': 1, 'nthread': 8, 'min_child_weight': 1, 'subsample': 0.9, 'eta': 0.1, 'objective': 'multi:softprob', 'max_depth': 3, 'gamma': 0.32}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 9 Mt
# 18 Nt
# 9.001 9.001
# 45 mt
# 180 nt
# (4296, 6) data_shape
# (4059, 12) X shape
# (4059, 1) y shape
# 72 no of classes
# top map results [{'map': 0.63710266666666671, 'max_depth': 3, 'min_child_weight': 1}, {'map': 0.63414633333333337, 'max_depth': 3, 'min_child_weight': 2}, {'map': 0.61123399999999994, 'max_depth': 2, 'min_child_weight': 1}]
# computed params for big grid 9, 18
# {'colsample_bytree': 0.7, 'silent': 0, 'scale_pos_weight': 1, 'nthread': 8, 'min_child_weight': 1, 'subsample': 0.9, 'eta': 0.1, 'objective': 'multi:softprob', 'max_depth': 3, 'gamma': 0.32}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 9 Mt
# 19 Nt
# 9.001 9.501
# 45 mt
# 190 nt
# (2795, 6) data_shape
# (2564, 12) X shape
# (2564, 1) y shape
# 55 no of classes
# top map results [{'map': 0.5694769999999999, 'max_depth': 3, 'min_child_weight': 1}, {'map': 0.56713499999999994, 'max_depth': 3, 'min_child_weight': 2}, {'map': 0.5242, 'max_depth': 2, 'min_child_weight': 1}]
# computed params for big grid 9, 19
# {'colsample_bytree': 0.7, 'silent': 0, 'scale_pos_weight': 1, 'nthread': 8, 'min_child_weight': 1, 'subsample': 0.9, 'eta': 0.1, 'objective': 'multi:softprob', 'max_depth': 3, 'gamma': 0.32}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

# %%
len(params_dict[0])
# Out:
# 201

# %%
g.max_n
# Out:
# 200

# %%
params_dict[5][61]
# Out:
# {'colsample_bytree': 0.7,
#  'eta': 0.1,
#  'gamma': 0.32,
#  'max_depth': 3,
#  'min_child_weight': 1,
#  'nthread': 8,
#  'objective': 'multi:softprob',
#  'scale_pos_weight': 1,
#  'silent': 0,
#  'subsample': 0.9}

# %%
params_dict[0][150]
# Out:
# {'colsample_bytree': 0.7,
#  'eta': 0.1,
#  'gamma': 0.32,
#  'max_depth': 3,
#  'min_child_weight': 1,
#  'nthread': 8,
#  'objective': 'multi:softprob',
#  'scale_pos_weight': 1,
#  'silent': 0,
#  'subsample': 0.9}
